# %%
#MonteCarlo Time of Arrival GPS Sim for Receiver Localization with Angle of Arrival
#Fausto Vega

using SatelliteDynamics
using LinearAlgebra
using PlotlyJS
using DelimitedFiles
using Distributions
using ForwardDiff
using BlockDiagonals
using Downloads
# Out:
# KERNEL EXCEPTION
# UndefVarError: setexcludinghandlers! not defined
#
# Stacktrace:
#   [1] set_nosync(ob::Observables.Observable{Dict{Any, Any}}, val::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:352
#   [2] dispatch(ctx::WebIO.Scope, key::String, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:368
#   [3] dispatch_command(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:104
#   [4] dispatch(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:81
#   [5] (::WebIO.var"#93#94"{WebIO.IJuliaConnection})(msg::IJulia.Msg)
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/providers/ijulia.jl:21
#   [6] comm_msg(sock::ZMQ.Socket, msg::IJulia.Msg)
#     @ IJulia.CommManager ~/.julia/packages/IJulia/e8kqU/src/comm_manager.jl:134
#   [7] #invokelatest#2
#     @ ./essentials.jl:708 [inlined]
#   [8] invokelatest
#     @ ./essentials.jl:706 [inlined]
#   [9] eventloop(socket::ZMQ.Socket)
#     @ IJulia ~/.julia/packages/IJulia/e8kqU/src/eventloop.jl:8
#  [10] (::IJulia.var"#15#18")()
#     @ IJulia ./task.jl:411
# KERNEL EXCEPTION
# UndefVarError: setexcludinghandlers! not defined
#
# Stacktrace:
#   [1] set_nosync(ob::Observables.Observable{Dict{Any, Any}}, val::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:352
#   [2] dispatch(ctx::WebIO.Scope, key::String, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:368
#   [3] dispatch_command(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:104
#   [4] dispatch(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:81
#   [5] (::WebIO.var"#93#94"{WebIO.IJuliaConnection})(msg::IJulia.Msg)
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/providers/ijulia.jl:21
#   [6] comm_msg(sock::ZMQ.Socket, msg::IJulia.Msg)
#     @ IJulia.CommManager ~/.julia/packages/IJulia/e8kqU/src/comm_manager.jl:134
#   [7] #invokelatest#2
#     @ ./essentials.jl:708 [inlined]
#   [8] invokelatest
#     @ ./essentials.jl:706 [inlined]
#   [9] eventloop(socket::ZMQ.Socket)
#     @ IJulia ~/.julia/packages/IJulia/e8kqU/src/eventloop.jl:8
#  [10] (::IJulia.var"#15#18")()
#     @ IJulia ./task.jl:411
# KERNEL EXCEPTION
# UndefVarError: setexcludinghandlers! not defined
#
# Stacktrace:
#   [1] set_nosync(ob::Observables.Observable{Dict{Any, Any}}, val::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:352
#   [2] dispatch(ctx::WebIO.Scope, key::String, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:368
#   [3] dispatch_command(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:104
#   [4] dispatch(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:81
#   [5] (::WebIO.var"#93#94"{WebIO.IJuliaConnection})(msg::IJulia.Msg)
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/providers/ijulia.jl:21
#   [6] comm_msg(sock::ZMQ.Socket, msg::IJulia.Msg)
#     @ IJulia.CommManager ~/.julia/packages/IJulia/e8kqU/src/comm_manager.jl:134
#   [7] #invokelatest#2
#     @ ./essentials.jl:708 [inlined]
#   [8] invokelatest
#     @ ./essentials.jl:706 [inlined]
#   [9] eventloop(socket::ZMQ.Socket)
#     @ IJulia ~/.julia/packages/IJulia/e8kqU/src/eventloop.jl:8
#  [10] (::IJulia.var"#15#18")()
#     @ IJulia ./task.jl:411

# %%
distance_scale = R_EARTH*(1e-3) # scales km to custom scale
time_scale = 1/(C_LIGHT/R_EARTH) #scales seconds to custom scale

c = 1 # 1 distance_unit/ 1 time_unit
# Out:
# 1

# %%
# Declare simulation initial Epoch. Start time
epc0 = Epoch(2019, 1, 1, 12, 0, 0, 0.0)  #year, month, day, hour, minute, seconds, nanoseconds
# Out:
# Epoch(2019-01-01T11:59:23.000Z)

# %%
# Declare initial state in terms of osculating orbital elements
#semi-major axis, eccentricity, inclination, RAAN, Argument of perigee, Mean anomaly

#1 and 2 on the same orbit, different initial mean anomaly

#previous configuration (working but not 100 km apart at the equator) (hard to do in practice)
#iss1 = [7378e3, 0.0004879, 90.6391, 189.0859, 151.2014, 185]; #converges at 189.0859
#iss2 = [7378e3, 0.0004879, 90.6391, 189.0859, 151.2014, 205];
#iss3 = [7378e3, 0.0004879, 90.6391, 201.0859, 151.2014, 190]; # converges a t 200.0859
#iss4 = [7378e3, 0.0004879, 90.6391, 201.0859, 151.2014, 215]; # converges a t 200.0859

#approximately 500 km elevation from surface of Earth and around 100 km seperation at equator
#working good
iss1 = [6871e3, 0.0004879, 90.6391, 194.5859, 151.2014, 190]; 
#iss2 = [6871e3, 0.0004879, 90.6391, 194.5859, 151.2014, 200];
iss3 = [6871e3, 0.0004879, 90.6391, 196.5859, 151.2014, 200]; 
#iss4 = [6871e3, 0.0004879, 90.6391, 196.5859, 151.2014, 203]; 

E1 = anomaly_mean_to_eccentric(iss1[6], iss1[2], use_degrees=true);
#E2 = anomaly_mean_to_eccentric(iss2[6], iss2[2], use_degrees=true);
E3 = anomaly_mean_to_eccentric(iss3[6], iss3[2], use_degrees=true);
#E4 = anomaly_mean_to_eccentric(iss4[6], iss4[2], use_degrees=true);

# %%
# Convert osculating elements to Cartesean state
# returns position and velocity (m, m/s)

eci0_1 = sOSCtoCART(iss1, use_degrees=true)
#eci0_2 = sOSCtoCART(iss2, use_degrees=true)
eci0_3 = sOSCtoCART(iss3, use_degrees=true)
#eci0_4 = sOSCtoCART(iss4, use_degrees=true)
# Out:
# 6-element Vector{Float64}:
#     -6.506916564822053e6
#     -1.9503165433100485e6
#     -1.0536819473539353e6
#  -1141.212504517901
#   -252.34537233835738
#   7522.817373459282

# %%
#compute the satellite orbital period given the semi-major axis

#same for all 4 satellites since they have the same semi-major axis
T = orbit_period(iss1[1])

#final time for one orbit. Adds initial time to the orbital period

epcf = epc0 + T
# Out:
# Epoch(2019-01-01T13:33:51.144Z)

# %%
# Create an EarthInertialState orbit propagagator
#needs initial epoch of state and the state vector
orb1  = EarthInertialState(epc0, eci0_1, dt=1.0,
            mass=1.0, n_grav=0, m_grav=0,
            drag=false, srp=false,
            moon=false, sun=false,
            relativity=false
)

# orb2  = EarthInertialState(epc0, eci0_2, dt=1.0,
#             mass=1.0, n_grav=0, m_grav=0,
#             drag=false, srp=false,
#             moon=false, sun=false,
#             relativity=false
# )

orb3  = EarthInertialState(epc0, eci0_3, dt=1.0,
            mass=1.0, n_grav=0, m_grav=0,
            drag=false, srp=false,
            moon=false, sun=false,
            relativity=false
)

# orb4  = EarthInertialState(epc0, eci0_4, dt=1.0,
#             mass=1.0, n_grav=0, m_grav=0,
#             drag=false, srp=false,
#             moon=false, sun=false,
#             relativity=false
# )

# Propagate the orbit
# orbit until the final time

t_1, epc_1, eci_1 = sim!(orb1, epcf);
#t_2, epc_2, eci_2 = sim!(orb2, epcf);
t_3, epc_3, eci_3 = sim!(orb3, epcf);
#t_4, epc_4, eci_4 = sim!(orb4, epcf);

# %%
#equator position in cartesian coordinates
#tag =[-6.128804e6, -1.590206e6, 776.1502e3]
#Equitorial position
tag_geof = [-165.4545, 0, 0]

#North pole position
#tag_geof = [-165.4545, 46.98849, 0]

tag = sGEOCtoECEF(tag_geof, use_degrees = true)
# Out:
# 3-element Vector{Float64}:
#  -6.173708155673107e6
#  -1.6018611673126891e6
#   0.0

# %%
#Equitorial Position
#In m
x0= tag[1] 
y0 = tag[2]
z0 = tag[3]
t0 = 1e-5

r0 = [x0, y0, z0, t0]

centroid_guess = [(eci_1[1,1]+eci_3[1,1])/4, (eci_1[2,1]+eci_3[2,1])/4, (eci_1[3,1]+eci_3[3,1])/4] 
onearth = sECEFtoGEOC(centroid_guess, use_degrees = true)
geodetic = [onearth[1], onearth[2], 0]

#Guess
xyz = sGEOCtoECEF(geodetic, use_degrees = true)

println(xyz)
# Out:
# [-5.960691167369461e6, -1.682718130118407e6, -1.5229090887454548e6]

# %%
#Plot Satellite 1 and 2 Orbit
sat1 = scatter(x=eci_1[1,:], y=eci_1[2,:], z=eci_1[3,:], type="scatter3d", mode="lines", name="orbit 1&2")

#Plot Satellite 3 and 4 Orbit
sat3 = scatter(x=eci_3[1,:], y=eci_3[2,:], z=eci_3[3,:], type="scatter3d", mode="lines", name="orbit 3&4")

#Plot all 4 satellite initial positions
satellites = scatter(x=[eci_1[1,1], eci_3[1,1]], y=[eci_1[2,1], eci_3[2,1]],z=[eci_1[3,1], eci_3[3,1]], mode="markers", marker_size = 4, type="scatter3d", name="satellites")

#Plot Tag position
tag = scatter(x = [r0[1], r0[1]], y = [r0[2], r0[2]], z = [r0[3], r0[3]], type="scatter3d", name="tag", mode="markers", marker_size=5)

#Plot the Guess
guess = scatter(x = [xyz[1], xyz[1]], y = [xyz[2], xyz[2]], z = [xyz[3], xyz[3]], type="scatter3d", name="guess", mode="markers", marker_size=5)

#Plotting the sphere (Earth)
n = 100
u = range(-π, π; length = n)
v = range(0, π; length = n)
x = cos.(u) * sin.(v)'
y = sin.(u) * sin.(v)' 
z = ones(n) * cos.(v)' 

#earth_img = load(Downloads.download("https://upload.wikimedia.org/wikipedia/commons/5/56/Blue_Marble_Next_Generation_%2B_topography_%2B_bathymetry.jpg"))

earth = surface(z=z*6371000, x=x*6371000, y=y*6371000, showscale = false)

plot([sat1,sat3, satellites, tag, earth, guess])
# Out:
# data: [
#   "scatter3d with fields mode, name, type, x, y, and z",
#   "scatter3d with fields mode, name, type, x, y, and z",
#   "scatter3d with fields marker, mode, name, type, x, y, and z",
#   "scatter3d with fields marker, mode, name, type, x, y, and z",
#   "surface with fields showscale, type, x, y, and z",
#   "scatter3d with fields marker, mode, name, type, x, y, and z"
# ]
#
# layout: "layout with fields margin and template"
# KERNEL EXCEPTION
# UndefVarError: setexcludinghandlers! not defined
#
# Stacktrace:
#   [1] set_nosync(ob::Observables.Observable{Dict{Any, Any}}, val::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:352
#   [2] dispatch(ctx::WebIO.Scope, key::String, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:368
#   [3] dispatch_command(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:104
#   [4] dispatch(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:81
#   [5] (::WebIO.var"#93#94"{WebIO.IJuliaConnection})(msg::IJulia.Msg)
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/providers/ijulia.jl:21
#   [6] comm_msg(sock::ZMQ.Socket, msg::IJulia.Msg)
#     @ IJulia.CommManager ~/.julia/packages/IJulia/e8kqU/src/comm_manager.jl:134
#   [7] #invokelatest#2
#     @ ./essentials.jl:708 [inlined]
#   [8] invokelatest
#     @ ./essentials.jl:706 [inlined]
#   [9] eventloop(socket::ZMQ.Socket)
#     @ IJulia ~/.julia/packages/IJulia/e8kqU/src/eventloop.jl:8
#  [10] (::IJulia.var"#15#18")()
#     @ IJulia ./task.jl:411

# %%
#Finding the Elevation Angle

function zenith_angle(satposes, r0)
    
    zenithangle = zeros(2)

    #vector between tag and the satellite
    normalvec = r0
    
    for i in 1:2
        
        vector = satposes[i,:] - r0[1:3]
        
        #Find the angle between the normal and the vector going from the tag to the satellte
        theta = acos(dot(normalvec,vector)/(norm(normalvec)*norm(vector))) * (180/pi)
        
        #save elevation angle
        zenithangle[i] = theta
    end
    
    return zenithangle
end
# Out:
# zenith_angle (generic function with 1 method)

# %%
#Testing elevation angle function
satposes = [eci_1[1,1] eci_1[2,1] eci_1[3,1];eci_3[1,1] eci_3[2,1] eci_3[3,1]]

zenith_angles = zenith_angle(satposes, r0[1:3])

println(zenith_angles)

#check all angles to see if it is on the horizon 
inhorizon = all(x->x<80, zenith_angles)
# Out:
# [86.66698734179924, 69.2759582272734]
# false

# %%
#Obtain the orbital elements after each time step 
dim = size(t_1)[1]

all_elements = zeros(6,dim)
for i in 1:dim
    
    orbital_elements = sCARTtoOSC(eci_1[:,1], use_degrees=true)
    all_elements[:,i] = orbital_elements
end
# Out:
# KERNEL EXCEPTION
# UndefVarError: setexcludinghandlers! not defined
#
# Stacktrace:
#   [1] set_nosync(ob::Observables.Observable{Dict{Any, Any}}, val::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:352
#   [2] dispatch(ctx::WebIO.Scope, key::String, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:368
#   [3] dispatch_command(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:104
#   [4] dispatch(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:81
#   [5] (::WebIO.var"#93#94"{WebIO.IJuliaConnection})(msg::IJulia.Msg)
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/providers/ijulia.jl:21
#   [6] comm_msg(sock::ZMQ.Socket, msg::IJulia.Msg)
#     @ IJulia.CommManager ~/.julia/packages/IJulia/e8kqU/src/comm_manager.jl:134
#   [7] #invokelatest#2
#     @ ./essentials.jl:708 [inlined]
#   [8] invokelatest
#     @ ./essentials.jl:706 [inlined]
#   [9] eventloop(socket::ZMQ.Socket)
#     @ IJulia ~/.julia/packages/IJulia/e8kqU/src/eventloop.jl:8
#  [10] (::IJulia.var"#15#18")()
#     @ IJulia ./task.jl:411

# %%
#plot(dim, all_elements[1,:], xlabel = "t (s)", ylabel = "a [km]", title = "Semi-major Axis",  ylims = (6.2e6, 7.4e6))
# Out:
# KERNEL EXCEPTION
# UndefVarError: setexcludinghandlers! not defined
#
# Stacktrace:
#   [1] set_nosync(ob::Observables.Observable{Dict{Any, Any}}, val::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:352
#   [2] dispatch(ctx::WebIO.Scope, key::String, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:368
#   [3] dispatch_command(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:104
#   [4] dispatch(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:81
#   [5] (::WebIO.var"#93#94"{WebIO.IJuliaConnection})(msg::IJulia.Msg)
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/providers/ijulia.jl:21
#   [6] comm_msg(sock::ZMQ.Socket, msg::IJulia.Msg)
#     @ IJulia.CommManager ~/.julia/packages/IJulia/e8kqU/src/comm_manager.jl:134
#   [7] #invokelatest#2
#     @ ./essentials.jl:708 [inlined]
#   [8] invokelatest
#     @ ./essentials.jl:706 [inlined]
#   [9] eventloop(socket::ZMQ.Socket)
#     @ IJulia ~/.julia/packages/IJulia/e8kqU/src/eventloop.jl:8
#  [10] (::IJulia.var"#15#18")()
#     @ IJulia ./task.jl:411

# %%
#plt = plot3d(1, xaxis=("x", (-6e6, 6e6)), yaxis=("y", (-5e6, 5e6)), zaxis=("z", (-5e6, 5e6)), title="ISS Orbit", marker=2, markercolor="black")

#anim = @animate for i in 1:dim
#    push!(plt, eci_1[1,i], eci_1[2,i], eci_1[3,i])
#    push!(plt, eci_2[1,i], eci_2[2,i], eci_2[3,i])
#    push!(plt, eci_3[1,i], eci_3[2,i], eci_3[3,i])
#    push!(plt, eci_4[1,i], eci_4[2,i], eci_4[3,i])
#end
# Out:
# KERNEL EXCEPTION
# UndefVarError: setexcludinghandlers! not defined
#
# Stacktrace:
#   [1] set_nosync(ob::Observables.Observable{Dict{Any, Any}}, val::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:352
#   [2] dispatch(ctx::WebIO.Scope, key::String, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:368
#   [3] dispatch_command(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:104
#   [4] dispatch(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:81
#   [5] (::WebIO.var"#93#94"{WebIO.IJuliaConnection})(msg::IJulia.Msg)
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/providers/ijulia.jl:21
#   [6] comm_msg(sock::ZMQ.Socket, msg::IJulia.Msg)
#     @ IJulia.CommManager ~/.julia/packages/IJulia/e8kqU/src/comm_manager.jl:134
#   [7] #invokelatest#2
#     @ ./essentials.jl:708 [inlined]
#   [8] invokelatest
#     @ ./essentials.jl:706 [inlined]
#   [9] eventloop(socket::ZMQ.Socket)
#     @ IJulia ~/.julia/packages/IJulia/e8kqU/src/eventloop.jl:8
#  [10] (::IJulia.var"#15#18")()
#     @ IJulia ./task.jl:411

# %%
#gif(anim, "orbit.gif", fps=1000)
# Out:
# KERNEL EXCEPTION
# UndefVarError: setexcludinghandlers! not defined
#
# Stacktrace:
#   [1] set_nosync(ob::Observables.Observable{Dict{Any, Any}}, val::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:352
#   [2] dispatch(ctx::WebIO.Scope, key::String, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:368
#   [3] dispatch_command(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:104
#   [4] dispatch(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:81
#   [5] (::WebIO.var"#93#94"{WebIO.IJuliaConnection})(msg::IJulia.Msg)
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/providers/ijulia.jl:21
#   [6] comm_msg(sock::ZMQ.Socket, msg::IJulia.Msg)
#     @ IJulia.CommManager ~/.julia/packages/IJulia/e8kqU/src/comm_manager.jl:134
#   [7] #invokelatest#2
#     @ ./essentials.jl:708 [inlined]
#   [8] invokelatest
#     @ ./essentials.jl:706 [inlined]
#   [9] eventloop(socket::ZMQ.Socket)
#     @ IJulia ~/.julia/packages/IJulia/e8kqU/src/eventloop.jl:8
#  [10] (::IJulia.var"#15#18")()
#     @ IJulia ./task.jl:411
# KERNEL EXCEPTION
# UndefVarError: setexcludinghandlers! not defined
#
# Stacktrace:
#   [1] set_nosync(ob::Observables.Observable{Dict{Any, Any}}, val::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:352
#   [2] dispatch(ctx::WebIO.Scope, key::String, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:368
#   [3] dispatch_command(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:104
#   [4] dispatch(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:81
#   [5] (::WebIO.var"#93#94"{WebIO.IJuliaConnection})(msg::IJulia.Msg)
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/providers/ijulia.jl:21
#   [6] comm_msg(sock::ZMQ.Socket, msg::IJulia.Msg)
#     @ IJulia.CommManager ~/.julia/packages/IJulia/e8kqU/src/comm_manager.jl:134
#   [7] #invokelatest#2
#     @ ./essentials.jl:708 [inlined]
#   [8] invokelatest
#     @ ./essentials.jl:706 [inlined]
#   [9] eventloop(socket::ZMQ.Socket)
#     @ IJulia ~/.julia/packages/IJulia/e8kqU/src/eventloop.jl:8
#  [10] (::IJulia.var"#15#18")()
#     @ IJulia ./task.jl:411
# KERNEL EXCEPTION
# UndefVarError: setexcludinghandlers! not defined
#
# Stacktrace:
#   [1] set_nosync(ob::Observables.Observable{Dict{Any, Any}}, val::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:352
#   [2] dispatch(ctx::WebIO.Scope, key::String, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:368
#   [3] dispatch_command(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:104
#   [4] dispatch(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:81
#   [5] (::WebIO.var"#93#94"{WebIO.IJuliaConnection})(msg::IJulia.Msg)
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/providers/ijulia.jl:21
#   [6] comm_msg(sock::ZMQ.Socket, msg::IJulia.Msg)
#     @ IJulia.CommManager ~/.julia/packages/IJulia/e8kqU/src/comm_manager.jl:134
#   [7] #invokelatest#2
#     @ ./essentials.jl:708 [inlined]
#   [8] invokelatest
#     @ ./essentials.jl:706 [inlined]
#   [9] eventloop(socket::ZMQ.Socket)
#     @ IJulia ~/.julia/packages/IJulia/e8kqU/src/eventloop.jl:8
#  [10] (::IJulia.var"#15#18")()
#     @ IJulia ./task.jl:411

# %%
#Generate TEC Distribution for night TEC values
mu = 8e16
sigma = 3e16
lb = 3e16
ub = 13e16
d = Truncated(Normal(mu,sigma), lb, ub)

#Generate TEC Distribution for day TEC values
#mu = 35e16
#sigma = 5e16
#lb = 30e16
#ub = 40e16
#d = Truncated(Normal(mu,sigma), lb, ub)

#f = 1575.42e6 # in 1/s L1 frequency

#f = 50e6
f = 400e6 # in 1/s system frequency
hi = 350e3 #in meters
Ip = zeros(2)
OF = zeros(2)
Iz = zeros(2)
Ip_scaled = zeros(2)
# Out:
# 2-element Vector{Float64}:
#  0.0
#  0.0
# KERNEL EXCEPTION
# UndefVarError: setexcludinghandlers! not defined
#
# Stacktrace:
#   [1] set_nosync(ob::Observables.Observable{Dict{Any, Any}}, val::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:352
#   [2] dispatch(ctx::WebIO.Scope, key::String, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:368
#   [3] dispatch_command(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:104
#   [4] dispatch(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:81
#   [5] (::WebIO.var"#93#94"{WebIO.IJuliaConnection})(msg::IJulia.Msg)
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/providers/ijulia.jl:21
#   [6] comm_msg(sock::ZMQ.Socket, msg::IJulia.Msg)
#     @ IJulia.CommManager ~/.julia/packages/IJulia/e8kqU/src/comm_manager.jl:134
#   [7] #invokelatest#2
#     @ ./essentials.jl:708 [inlined]
#   [8] invokelatest
#     @ ./essentials.jl:706 [inlined]
#   [9] eventloop(socket::ZMQ.Socket)
#     @ IJulia ~/.julia/packages/IJulia/e8kqU/src/eventloop.jl:8
#  [10] (::IJulia.var"#15#18")()
#     @ IJulia ./task.jl:411
# KERNEL EXCEPTION
# UndefVarError: setexcludinghandlers! not defined
#
# Stacktrace:
#   [1] set_nosync(ob::Observables.Observable{Dict{Any, Any}}, val::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:352
#   [2] dispatch(ctx::WebIO.Scope, key::String, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:368
#   [3] dispatch_command(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:104
#   [4] dispatch(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:81
#   [5] (::WebIO.var"#93#94"{WebIO.IJuliaConnection})(msg::IJulia.Msg)
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/providers/ijulia.jl:21
#   [6] comm_msg(sock::ZMQ.Socket, msg::IJulia.Msg)
#     @ IJulia.CommManager ~/.julia/packages/IJulia/e8kqU/src/comm_manager.jl:134
#   [7] #invokelatest#2
#     @ ./essentials.jl:708 [inlined]
#   [8] invokelatest
#     @ ./essentials.jl:706 [inlined]
#   [9] eventloop(socket::ZMQ.Socket)
#     @ IJulia ~/.julia/packages/IJulia/e8kqU/src/eventloop.jl:8
#  [10] (::IJulia.var"#15#18")()
#     @ IJulia ./task.jl:411
# KERNEL EXCEPTION
# UndefVarError: setexcludinghandlers! not defined
#
# Stacktrace:
#   [1] set_nosync(ob::Observables.Observable{Dict{Any, Any}}, val::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:352
#   [2] dispatch(ctx::WebIO.Scope, key::String, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:368
#   [3] dispatch_command(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:104
#   [4] dispatch(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:81
#   [5] (::WebIO.var"#93#94"{WebIO.IJuliaConnection})(msg::IJulia.Msg)
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/providers/ijulia.jl:21
#   [6] comm_msg(sock::ZMQ.Socket, msg::IJulia.Msg)
#     @ IJulia.CommManager ~/.julia/packages/IJulia/e8kqU/src/comm_manager.jl:134
#   [7] #invokelatest#2
#     @ ./essentials.jl:708 [inlined]
#   [8] invokelatest
#     @ ./essentials.jl:706 [inlined]
#   [9] eventloop(socket::ZMQ.Socket)
#     @ IJulia ~/.julia/packages/IJulia/e8kqU/src/eventloop.jl:8
#  [10] (::IJulia.var"#15#18")()
#     @ IJulia ./task.jl:411
# KERNEL EXCEPTION
# UndefVarError: setexcludinghandlers! not defined
#
# Stacktrace:
#   [1] set_nosync(ob::Observables.Observable{Dict{Any, Any}}, val::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:352
#   [2] dispatch(ctx::WebIO.Scope, key::String, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:368
#   [3] dispatch_command(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:104
#   [4] dispatch(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:81
#   [5] (::WebIO.var"#93#94"{WebIO.IJuliaConnection})(msg::IJulia.Msg)
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/providers/ijulia.jl:21
#   [6] comm_msg(sock::ZMQ.Socket, msg::IJulia.Msg)
#     @ IJulia.CommManager ~/.julia/packages/IJulia/e8kqU/src/comm_manager.jl:134
#   [7] #invokelatest#2
#     @ ./essentials.jl:708 [inlined]
#   [8] invokelatest
#     @ ./essentials.jl:706 [inlined]
#   [9] eventloop(socket::ZMQ.Socket)
#     @ IJulia ~/.julia/packages/IJulia/e8kqU/src/eventloop.jl:8
#  [10] (::IJulia.var"#15#18")()
#     @ IJulia ./task.jl:411
# KERNEL EXCEPTION
# UndefVarError: setexcludinghandlers! not defined
#
# Stacktrace:
#   [1] set_nosync(ob::Observables.Observable{Dict{Any, Any}}, val::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:352
#   [2] dispatch(ctx::WebIO.Scope, key::String, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:368
#   [3] dispatch_command(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:104
#   [4] dispatch(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:81
#   [5] (::WebIO.var"#93#94"{WebIO.IJuliaConnection})(msg::IJulia.Msg)
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/providers/ijulia.jl:21
#   [6] comm_msg(sock::ZMQ.Socket, msg::IJulia.Msg)
#     @ IJulia.CommManager ~/.julia/packages/IJulia/e8kqU/src/comm_manager.jl:134
#   [7] #invokelatest#2
#     @ ./essentials.jl:708 [inlined]
#   [8] invokelatest
#     @ ./essentials.jl:706 [inlined]
#   [9] eventloop(socket::ZMQ.Socket)
#     @ IJulia ~/.julia/packages/IJulia/e8kqU/src/eventloop.jl:8
#  [10] (::IJulia.var"#15#18")()
#     @ IJulia ./task.jl:411
# KERNEL EXCEPTION
# UndefVarError: setexcludinghandlers! not defined
#
# Stacktrace:
#   [1] set_nosync(ob::Observables.Observable{Dict{Any, Any}}, val::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:352
#   [2] dispatch(ctx::WebIO.Scope, key::String, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:368
#   [3] dispatch_command(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:104
#   [4] dispatch(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:81
#   [5] (::WebIO.var"#93#94"{WebIO.IJuliaConnection})(msg::IJulia.Msg)
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/providers/ijulia.jl:21
#   [6] comm_msg(sock::ZMQ.Socket, msg::IJulia.Msg)
#     @ IJulia.CommManager ~/.julia/packages/IJulia/e8kqU/src/comm_manager.jl:134
#   [7] #invokelatest#2
#     @ ./essentials.jl:708 [inlined]
#   [8] invokelatest
#     @ ./essentials.jl:706 [inlined]
#   [9] eventloop(socket::ZMQ.Socket)
#     @ IJulia ~/.julia/packages/IJulia/e8kqU/src/eventloop.jl:8
#  [10] (::IJulia.var"#15#18")()
#     @ IJulia ./task.jl:411
# KERNEL EXCEPTION
# UndefVarError: setexcludinghandlers! not defined
#
# Stacktrace:
#   [1] set_nosync(ob::Observables.Observable{Dict{Any, Any}}, val::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:352
#   [2] dispatch(ctx::WebIO.Scope, key::String, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:368
#   [3] dispatch_command(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:104
#   [4] dispatch(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:81
#   [5] (::WebIO.var"#93#94"{WebIO.IJuliaConnection})(msg::IJulia.Msg)
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/providers/ijulia.jl:21
#   [6] comm_msg(sock::ZMQ.Socket, msg::IJulia.Msg)
#     @ IJulia.CommManager ~/.julia/packages/IJulia/e8kqU/src/comm_manager.jl:134
#   [7] #invokelatest#2
#     @ ./essentials.jl:708 [inlined]
#   [8] invokelatest
#     @ ./essentials.jl:706 [inlined]
#   [9] eventloop(socket::ZMQ.Socket)
#     @ IJulia ~/.julia/packages/IJulia/e8kqU/src/eventloop.jl:8
#  [10] (::IJulia.var"#15#18")()
#     @ IJulia ./task.jl:411
# KERNEL EXCEPTION
# UndefVarError: setexcludinghandlers! not defined
#
# Stacktrace:
#   [1] set_nosync(ob::Observables.Observable{Dict{Any, Any}}, val::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:352
#   [2] dispatch(ctx::WebIO.Scope, key::String, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:368
#   [3] dispatch_command(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:104
#   [4] dispatch(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:81
#   [5] (::WebIO.var"#93#94"{WebIO.IJuliaConnection})(msg::IJulia.Msg)
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/providers/ijulia.jl:21
#   [6] comm_msg(sock::ZMQ.Socket, msg::IJulia.Msg)
#     @ IJulia.CommManager ~/.julia/packages/IJulia/e8kqU/src/comm_manager.jl:134
#   [7] #invokelatest#2
#     @ ./essentials.jl:708 [inlined]
#   [8] invokelatest
#     @ ./essentials.jl:706 [inlined]
#   [9] eventloop(socket::ZMQ.Socket)
#     @ IJulia ~/.julia/packages/IJulia/e8kqU/src/eventloop.jl:8
#  [10] (::IJulia.var"#15#18")()
#     @ IJulia ./task.jl:411
# KERNEL EXCEPTION
# UndefVarError: setexcludinghandlers! not defined
#
# Stacktrace:
#   [1] set_nosync(ob::Observables.Observable{Dict{Any, Any}}, val::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:352
#   [2] dispatch(ctx::WebIO.Scope, key::String, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:368
#   [3] dispatch_command(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:104
#   [4] dispatch(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:81
#   [5] (::WebIO.var"#93#94"{WebIO.IJuliaConnection})(msg::IJulia.Msg)
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/providers/ijulia.jl:21
#   [6] comm_msg(sock::ZMQ.Socket, msg::IJulia.Msg)
#     @ IJulia.CommManager ~/.julia/packages/IJulia/e8kqU/src/comm_manager.jl:134
#   [7] #invokelatest#2
#     @ ./essentials.jl:708 [inlined]
#   [8] invokelatest
#     @ ./essentials.jl:706 [inlined]
#   [9] eventloop(socket::ZMQ.Socket)
#     @ IJulia ~/.julia/packages/IJulia/e8kqU/src/eventloop.jl:8
#  [10] (::IJulia.var"#15#18")()
#     @ IJulia ./task.jl:411
# KERNEL EXCEPTION
# UndefVarError: setexcludinghandlers! not defined
#
# Stacktrace:
#   [1] set_nosync(ob::Observables.Observable{Dict{Any, Any}}, val::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:352
#   [2] dispatch(ctx::WebIO.Scope, key::String, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:368
#   [3] dispatch_command(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:104
#   [4] dispatch(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:81
#   [5] (::WebIO.var"#93#94"{WebIO.IJuliaConnection})(msg::IJulia.Msg)
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/providers/ijulia.jl:21
#   [6] comm_msg(sock::ZMQ.Socket, msg::IJulia.Msg)
#     @ IJulia.CommManager ~/.julia/packages/IJulia/e8kqU/src/comm_manager.jl:134
#   [7] #invokelatest#2
#     @ ./essentials.jl:708 [inlined]
#   [8] invokelatest
#     @ ./essentials.jl:706 [inlined]
#   [9] eventloop(socket::ZMQ.Socket)
#     @ IJulia ~/.julia/packages/IJulia/e8kqU/src/eventloop.jl:8
#  [10] (::IJulia.var"#15#18")()
#     @ IJulia ./task.jl:411
# KERNEL EXCEPTION
# UndefVarError: setexcludinghandlers! not defined
#
# Stacktrace:
#   [1] set_nosync(ob::Observables.Observable{Dict{Any, Any}}, val::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:352
#   [2] dispatch(ctx::WebIO.Scope, key::String, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:368
#   [3] dispatch_command(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:104
#   [4] dispatch(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:81
#   [5] (::WebIO.var"#93#94"{WebIO.IJuliaConnection})(msg::IJulia.Msg)
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/providers/ijulia.jl:21
#   [6] comm_msg(sock::ZMQ.Socket, msg::IJulia.Msg)
#     @ IJulia.CommManager ~/.julia/packages/IJulia/e8kqU/src/comm_manager.jl:134
#   [7] #invokelatest#2
#     @ ./essentials.jl:708 [inlined]
#   [8] invokelatest
#     @ ./essentials.jl:706 [inlined]
#   [9] eventloop(socket::ZMQ.Socket)
#     @ IJulia ~/.julia/packages/IJulia/e8kqU/src/eventloop.jl:8
#  [10] (::IJulia.var"#15#18")()
#     @ IJulia ./task.jl:411
# KERNEL EXCEPTION
# UndefVarError: setexcludinghandlers! not defined
#
# Stacktrace:
#   [1] set_nosync(ob::Observables.Observable{Dict{Any, Any}}, val::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:352
#   [2] dispatch(ctx::WebIO.Scope, key::String, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:368
#   [3] dispatch_command(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:104
#   [4] dispatch(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:81
#   [5] (::WebIO.var"#93#94"{WebIO.IJuliaConnection})(msg::IJulia.Msg)
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/providers/ijulia.jl:21
#   [6] comm_msg(sock::ZMQ.Socket, msg::IJulia.Msg)
#     @ IJulia.CommManager ~/.julia/packages/IJulia/e8kqU/src/comm_manager.jl:134
#   [7] #invokelatest#2
#     @ ./essentials.jl:708 [inlined]
#   [8] invokelatest
#     @ ./essentials.jl:706 [inlined]
#   [9] eventloop(socket::ZMQ.Socket)
#     @ IJulia ~/.julia/packages/IJulia/e8kqU/src/eventloop.jl:8
#  [10] (::IJulia.var"#15#18")()
#     @ IJulia ./task.jl:411
# KERNEL EXCEPTION
# UndefVarError: setexcludinghandlers! not defined
#
# Stacktrace:
#   [1] set_nosync(ob::Observables.Observable{Dict{Any, Any}}, val::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:352
#   [2] dispatch(ctx::WebIO.Scope, key::String, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:368
#   [3] dispatch_command(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:104
#   [4] dispatch(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:81
#   [5] (::WebIO.var"#93#94"{WebIO.IJuliaConnection})(msg::IJulia.Msg)
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/providers/ijulia.jl:21
#   [6] comm_msg(sock::ZMQ.Socket, msg::IJulia.Msg)
#     @ IJulia.CommManager ~/.julia/packages/IJulia/e8kqU/src/comm_manager.jl:134
#   [7] #invokelatest#2
#     @ ./essentials.jl:708 [inlined]
#   [8] invokelatest
#     @ ./essentials.jl:706 [inlined]
#   [9] eventloop(socket::ZMQ.Socket)
#     @ IJulia ~/.julia/packages/IJulia/e8kqU/src/eventloop.jl:8
#  [10] (::IJulia.var"#15#18")()
#     @ IJulia ./task.jl:411

# %%
dunit = 1/distance_scale
tunit = 1/time_scale
speed = dunit/tunit
# Out:
# 3.33564095198152e-6
# KERNEL EXCEPTION
# UndefVarError: setexcludinghandlers! not defined
#
# Stacktrace:
#   [1] set_nosync(ob::Observables.Observable{Dict{Any, Any}}, val::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:352
#   [2] dispatch(ctx::WebIO.Scope, key::String, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:368
#   [3] dispatch_command(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:104
#   [4] dispatch(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:81
#   [5] (::WebIO.var"#93#94"{WebIO.IJuliaConnection})(msg::IJulia.Msg)
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/providers/ijulia.jl:21
#   [6] comm_msg(sock::ZMQ.Socket, msg::IJulia.Msg)
#     @ IJulia.CommManager ~/.julia/packages/IJulia/e8kqU/src/comm_manager.jl:134
#   [7] #invokelatest#2
#     @ ./essentials.jl:708 [inlined]
#   [8] invokelatest
#     @ ./essentials.jl:706 [inlined]
#   [9] eventloop(socket::ZMQ.Socket)
#     @ IJulia ~/.julia/packages/IJulia/e8kqU/src/eventloop.jl:8
#  [10] (::IJulia.var"#15#18")()
#     @ IJulia ./task.jl:411

# %%
function measurment_residual(r0, r1, r2, t)
    
    omega = OMEGA_EARTH*time_scale
    
    #pass in as column vectors
    res1 = (norm(r0[1:3] - ([cos(omega*t[1]) sin(omega*t[1]) 0;
          -sin(omega*t[1]) cos(omega*t[1]) 0;
          0 0 1]) * r1[1:3]))/c + r0[4] - t[1]
    res2 = (norm(r0[1:3] - ([cos(omega*t[2]) sin(omega*t[2]) 0;
          -sin(omega*t[2]) cos(omega*t[2]) 0;
          0 0 1])* r2[1:3]))/c + r0[4] - t[2] 
#     res3 = (norm(r0[1:3] - ([cos(omega*t[3]) sin(omega*t[3]) 0;
#           -sin(omega*t[3]) cos(omega*t[3]) 0;
#           0 0 1])*r3[1:3]))/c + r0[4] - t[3] 
#     res4 = (norm(r0[1:3] - ([cos(omega*t[4]) sin(omega*t[4]) 0;
#           -sin(omega*t[4]) cos(omega*t[4]) 0;
#           0 0 1])*r4[1:3]))/c + r0[4] - t[4]
    
    #return [res1, res2, res3, res4]
    
    return [res1, res2]
end
# Out:
# measurment_residual (generic function with 1 method)

# %%
function get_time(r0_scaled, r1, r2)
    
    n = 1000

    time = [zeros(4) for i = 1:1000]
    Rt = [zeros(3) for i = 1:1000]

    time[1] = [0.1\time_scale, 0.1\time_scale] #initial guess

    Rt[1] = measurment_residual(r0_scaled, r1, r2, time[1])

    iters = 0

    for i=1:n

        Rt[i] = measurment_residual(r0_scaled, r1, r2, time[i])

        iters += 1

        if(norm(Rt[i]) < 1e-10) #-6 works
            break
        end

        jacobian = ForwardDiff.jacobian(dt -> measurment_residual(r0_scaled, r1, r2, dt), time[i])

        deltat = (jacobian)\-Rt[i]

        time[i+1]  = time[i] + deltat
    end
    
    Rt = Rt[1:iters]
    time = time[1:iters]
    time_measurment = time[end]
    
    return time_measurment
    
end
# Out:
# get_time (generic function with 1 method)

# %%
function residual(x, sat_pose_t, delta_t)
    
    #x[1:3] is the satellite pose
    #x[4]
    omega = OMEGA_EARTH*time_scale

    A1_1 = [cos(omega*sat_pose_t[1,4]) sin(omega*sat_pose_t[1,4]) 0;
          -sin(omega*sat_pose_t[1,4]) cos(omega*sat_pose_t[1,4]) 0;
          0 0 1];
    A1_2 = [cos(omega*sat_pose_t[2,4]) sin(omega*sat_pose_t[2,4]) 0;
          -sin(omega*sat_pose_t[2,4]) cos(omega*sat_pose_t[2,4]) 0;
          0 0 1];
    A1_3 = [cos(omega*sat_pose_t[3,4]) sin(omega*sat_pose_t[3,4]) 0;
          -sin(omega*sat_pose_t[3,4]) cos(omega*sat_pose_t[3,4]) 0;
          0 0 1];
    
    A2_1 = [cos(omega*sat_pose_t[4,4]) sin(omega*sat_pose_t[4,4]) 0;
          -sin(omega*sat_pose_t[4,4]) cos(omega*sat_pose_t[4,4]) 0;
          0 0 1];
    A2_2 = [cos(omega*sat_pose_t[5,4]) sin(omega*sat_pose_t[5,4]) 0;
          -sin(omega*sat_pose_t[5,4]) cos(omega*sat_pose_t[5,4]) 0;
          0 0 1];
    A2_3 = [cos(omega*sat_pose_t[6,4]) sin(omega*sat_pose_t[6,4]) 0;
          -sin(omega*sat_pose_t[6,4]) cos(omega*sat_pose_t[6,4]) 0;
          0 0 1];
    
    
#     A3 = [cos(omega*sat_pose_t[3,4]) sin(omega*sat_pose_t[3,4]) 0;
#           -sin(omega*sat_pose_t[3,4]) cos(omega*sat_pose_t[3,4]) 0;
#           0 0 1];
#     A4 = [cos(omega*sat_pose_t[4,4]) sin(omega*sat_pose_t[4,4]) 0;
#           -sin(omega*sat_pose_t[4,4]) cos(omega*sat_pose_t[4,4]) 0;
#           0 0 1];
    
    t1_1 = norm(x[1:3] - A1_1*sat_pose_t[1,1:3]) + c*(x[4]);
    t1_2 = norm(x[1:3] - A1_2*sat_pose_t[2,1:3]) + c*(x[4]);
    t1_3 = norm(x[1:3] - A1_3*sat_pose_t[3,1:3]) + c*(x[4]);
    #t4_1 = norm(x[1:3] - A4*sat_pose_t[4,1:3]) + c*(x[4]);
    
    t2_1 = norm(x[1:3] - A2_1*sat_pose_t[4,1:3]) + c*(x[4]);
    t2_2 = norm(x[1:3] - A2_2*sat_pose_t[5,1:3]) + c*(x[4]);
    t2_3 = norm(x[1:3] - A2_3*sat_pose_t[6,1:3]) + c*(x[4]);
    #t4_2 = norm(x[1:3] - A4*sat_pose_t[8,1:3]) + c*(x[4]);
    
    #t3_1 = norm(x[1:3] - A3*sat_pose_t[7,1:3]) + c*(x[4]);
    #t3_2 = norm(x[1:3] - A3*sat_pose_t[8,1:3]) + c*(x[4]);
    #t3_3 = norm(x[1:3] - A3*sat_pose_t[9,1:3]) + c*(x[4]);
    #t4_3 = norm(x[1:3] - A4*sat_pose_t[12,1:3]) + c*(x[4]);
    
    delta1_1 = t1_1 - t1_2
    delta1_2 = t1_1 - t1_3
    delta1_3 = t1_2 - t1_3
    
    delta2_1 = t2_1 - t2_2
    delta2_2 = t2_1 - t2_3
    delta2_3 = t2_2 - t2_3
    
    #delta3_1 = t3_1 - t3_2
    #delta3_2 = t3_1 - t3_3
    #delta3_3 = t3_2 - t3_3
    
    #delta4_1 = t4_1 - t4_2
    #delta4_2 = t4_1 - t4_3
    #delta4_3 = t4_2 - t4_3
    
    res1 = delta1_1 - delta_t[1,1]
    res2 = delta1_2 - delta_t[1,2]
    res3 = delta1_3 - delta_t[1,3]
    res4 = delta2_1 - delta_t[2,1]
    res5 = delta2_2 - delta_t[2,2]
    res6 = delta2_3 - delta_t[2,3]
    #res7 = delta3_1 - delta_t[3,1]
    #res8 = delta3_2 - delta_t[3,2]
    #res9 = delta3_3 - delta_t[3,3]
    #res10 = delta4_1 - delta_t[4,1]
    #res11 = delta4_2 - delta_t[4,2]
    #res12 = delta4_3 - delta_t[4,3]
    
#     delta2_1 = t_1[2] - t_2[2]
#     delta2_2 = t_1[2] - t_3[2]
#     delta2_3 = t_2[2] - t_3[2]
    
#     delta3_1 = t_1[3] - t_2[3]
#     delta3_2 = t_1[3] - t_3[3]
#     delta3_3 = t_2[3] - t_3[3]
    
#     delta4_1 = t_1[4] - t_2[4]
#     delta4_2 = t_1[4] - t_3[4]
#     delta4_3 = t_2[4] - t_3[4]
    
    residuals = [res1, res2, res3, res4, res5, res6]
    
    return residuals
    
#     return [norm(x[1:3] - A1*sat_pose_t[1,1:3]) - c*(sat_pose_t[1,4] - x[4]);
#             norm(x[1:3] - A2*sat_pose_t[2,1:3]) - c*(sat_pose_t[2,4] - x[4]);
#             norm(x[1:3] - A3*sat_pose_t[3,1:3]) - c*(sat_pose_t[3,4] - x[4]);
#             norm(x[1:3] - A4*sat_pose_t[4,1:3]) - c*(sat_pose_t[4,4] - x[4])]
end
# Out:
# residual (generic function with 1 method)

# %%
#Equitorial Position

#In km
x0= x0*1e-3
y0 = y0*1e-3
z0 = z0*1e-3
t0 = 1e-5

#r0 = [x0,y0,z0,t0]
r0_scaled = [x0/distance_scale, y0/distance_scale, z0/distance_scale, t0/time_scale]
# Out:
# 4-element Vector{Float64}:
#  -0.9679486083847263
#  -0.2511487826487322
#   0.0
#   0.0004700314384940316

# %%
#clock error distribution
mu_t = 0
sigma_t = 20e-9 #RMSE for Novatel GPS receiver
lb_t = 1e-9
ub_t = 30e-9
d_t = Truncated(Normal(mu_t,sigma_t), lb_t, ub_t)
# Out:
# Truncated(Normal{Float64}(μ=0.0, σ=2.0e-8); lower=1.0e-9, upper=3.0e-8)

# %%
clocknoise = rand(d_t,3)
# Out:
# 3-element Vector{Float64}:
#  6.902937283303633e-9
#  2.7617242717659583e-8
#  6.505014962984275e-9

# %%
function hat(axis_unit)
    return [0 -axis_unit[3] axis_unit[2]; axis_unit[3] 0 -axis_unit[1]; -axis_unit[2] axis_unit[1] 0]
end
# Out:
# hat (generic function with 1 method)

# %%
function receiver_pose(all_sats_scaled, guess, zenith_angles) # remember to scale the guess to custom units

    n = 1000 # number of iterations
    #all_r0 = NaN*[zeros(4) for i = 1:n]
    all_r0 = [zeros(4) for i = 1:n]
    
    
    sat1poses = zeros(4,n)
    sat2poses = zeros(4,n)
    #sat3poses = zeros(4,n)
    #sat4poses = zeros(4,n)

    all_sats_noise = zeros(4,4)

    iters = 0

     #Monte Carlo Simulation
    for i in 1:n
        b = 0.01
        c=0.5
        β = 10
        α = 1
        
        #create noise from random distribution
        #scaled to the variable (0.1m error for distance & 1e-11 for time)
        gpsnoise = randn(6)*(1e-4/distance_scale) #adding a 0.1 meter of noise
        #clocknoise = randn(4)*(1e-11/time_scale)
        clocknoise = rand(d_t,6)/time_scale
        #iterations = 0
        
        TEC = rand(d,2) #vTEC for each satellite from custom distribution
        
        #println("this is tEC: ", TEC)
        
        #Calculating random TEC time delay
        for i=1:2
        
            OF[i] = (1-((R_EARTH*sind(zenith_angles[i]))/(R_EARTH+hi))^2)^(-1/2) #normal units (m and s)
            Ip[i] = ((40.3*TEC[i])/(f^2))*OF[i] * 1e-3 #scale to km 
            Ip_scaled[i] = Ip[i]/distance_scale #scale to custom units
        
        end
        
        #Generate Random Rotation to account for spacecraft attitude error
        
        #Find transformation matrices to change from body to inertial frame
        
        p1 = [all_sats_scaled[1,1], all_sats_scaled[1,2], all_sats_scaled[1,3]]*1e3*distance_scale #distance from inertial to body
        p2 = [all_sats_scaled[4,1], all_sats_scaled[4,2], all_sats_scaled[4,3]]*1e3*distance_scale #distance from inertial to body
        
        #println("this is p1: ", p1)
        G1 = [I(3) p1; zeros(3)' 1]
        G2 = [I(3) p2; zeros(3)' 1]

        #sat 1 antennas 2 and 3 in the body frame in meters
        sat1_antenna2_body = [antenna_sep, 0, 0]#*1e-3/distance_scale
        sat1_antenna3_body = [-antenna_sep, 0, 0]#*1e-3/distance_scale
        
        #sat 2 antennas 2 and 3 in the body frame
        sat2_antenna2_body = [antenna_sep, 0, 0]#*1e-3/distance_scale
        sat2_antenna3_body = [-antenna_sep, 0, 0]#*1e-3/distance_scale
        
        #Generate 2 axes of rotation (1 for each sat). These axes are in the body frame
        axis = randn(6) #*1e-3/distance_scale
        #axis = [1,0,0,1,0,0,1,0,0]
        
        #Normalize the axes
        axis1_unit = axis[1:3]/norm(axis[1:3])
        axis2_unit = axis[4:6]/norm(axis[4:6])
        
        #Error of only a few degrees
        θ = randn(2)*(pi/180)*0.0027 # in radians
        
        #Find omega hat (skew symmetric matrix)
        ω1 = hat(axis1_unit)
        ω2 = hat(axis2_unit)
        
        #Find the 3 random rotation matrices
        R1 = exp(θ[1]*ω1)
        R2 = exp(θ[2]*ω2)
        
        #Apply a random rotation to the other 2 antenna pose  # in meters
        sat1_2_pose_og = [all_sats_scaled[2,1], all_sats_scaled[2,2], all_sats_scaled[2,3]]*1e3*distance_scale 
        sat1_3_pose_og = [all_sats_scaled[3,1], all_sats_scaled[3,2], all_sats_scaled[3,3]]*1e3*distance_scale
        
        sat2_2_pose_og = [all_sats_scaled[5,1], all_sats_scaled[5,2], all_sats_scaled[5,3]]*1e3*distance_scale 
        sat2_3_pose_og = [all_sats_scaled[6,1], all_sats_scaled[6,2], all_sats_scaled[6,3]]*1e3*distance_scale 
        
#         #Apply a random rotation to the other 2 antenna pose 
#         sat1_2_pose = R1*[all_sats_scaled[2,1], all_sats_scaled[2,2], all_sats_scaled[2,3]] 
#         sat1_3_pose = R1*[all_sats_scaled[3,1], all_sats_scaled[3,2], all_sats_scaled[3,3]] 
        
#         sat2_2_pose = R2*[all_sats_scaled[5,1], all_sats_scaled[5,2], all_sats_scaled[5,3]] 
#         sat2_3_pose = R2*[all_sats_scaled[6,1], all_sats_scaled[6,2], all_sats_scaled[6,3]] 
        
#         sat3_2_pose = R3*[all_sats_scaled[8,1], all_sats_scaled[8,2], all_sats_scaled[8,3]] 
#         sat3_3_pose = R3*[all_sats_scaled[9,1], all_sats_scaled[9,2], all_sats_scaled[9,3]] 
        
        #All in the body frame
        sat1_2_pose = R1*sat1_antenna2_body
        sat1_3_pose = R1*sat1_antenna3_body 
        
        sat2_2_pose = R2*sat2_antenna2_body 
        sat2_3_pose = R2*sat2_antenna3_body
        
        #Convert back to the inertial frame
        sat1_2_pose_inertial = (G1*[sat1_2_pose[1], sat1_2_pose[2], sat1_2_pose[3],1])*1e-3/distance_scale
        sat1_3_pose_inertial = (G1*[sat1_3_pose[1], sat1_3_pose[2], sat1_3_pose[3],1])*1e-3/distance_scale
        
        sat2_2_pose_inertial = (G2*[sat2_2_pose[1], sat2_2_pose[2], sat2_2_pose[3],1])*1e-3/distance_scale 
        sat2_3_pose_inertial = (G2*[sat2_3_pose[1], sat2_3_pose[2], sat2_3_pose[3],1])*1e-3/distance_scale
        
#         println("how rotation effects pose: ")
#         println(norm(sat1_2_pose_og - (sat1_2_pose_inertial[1:3]*1e3*distance_scale)))
#         println(norm(sat1_3_pose_og - (sat1_3_pose_inertial[1:3]*1e3*distance_scale)))
#         println(norm(sat2_2_pose_og - (sat2_2_pose_inertial[1:3]*1e3*distance_scale)))
#         println(norm(sat2_3_pose_og - (sat2_3_pose_inertial[1:3]*1e3*distance_scale)))
        
        #println("this is the difference")
        #println(norm(all_sats_scaled[2,1:3] - sat1_2_pose_inertial[1:3]))
        
        #sat 1 with all 3 antennas
        sat1_1_noise = [all_sats_scaled[1,1]+gpsnoise[1],all_sats_scaled[1,2] + gpsnoise[2],all_sats_scaled[1,3]+gpsnoise[3], all_sats_scaled[1,4] + clocknoise[1]+ (Ip_scaled[1]/c)]
        sat1_2_noise =[sat1_2_pose_inertial[1]+gpsnoise[1],sat1_2_pose_inertial[2] + gpsnoise[2],sat1_2_pose_inertial[3]+gpsnoise[3], all_sats_scaled[2,4] + clocknoise[2]+ (Ip_scaled[1]/c)]
        sat1_3_noise = [sat1_3_pose_inertial[1]+gpsnoise[1],sat1_3_pose_inertial[2] + gpsnoise[2],sat1_3_pose_inertial[3]+gpsnoise[3], all_sats_scaled[3,4] + clocknoise[3]+ (Ip_scaled[1]/c)]
        
        #sat 2 with all 3 antennas
        sat2_1_noise = [all_sats_scaled[4,1]+gpsnoise[4],all_sats_scaled[4,2] + gpsnoise[5],all_sats_scaled[4,3]+gpsnoise[6], all_sats_scaled[4,4] + clocknoise[4]+ (Ip_scaled[2]/c)]
        sat2_2_noise =[sat2_2_pose_inertial[1]+gpsnoise[4],sat2_2_pose_inertial[2] + gpsnoise[5],sat2_2_pose_inertial[3]+gpsnoise[6], all_sats_scaled[5,4] + clocknoise[5]+ (Ip_scaled[2]/c)]
        sat2_3_noise = [sat2_3_pose_inertial[1]+gpsnoise[4],sat2_3_pose_inertial[2] + gpsnoise[5],sat2_3_pose_inertial[3]+gpsnoise[6], all_sats_scaled[6,4] + clocknoise[6]+ (Ip_scaled[2]/c)]
        
        all_sats_noise = vcat(sat1_1_noise',sat1_2_noise',sat1_3_noise',sat2_1_noise',sat2_2_noise',sat2_3_noise')
        
        delta1_1 = all_sats_scaled[1,4] - all_sats_scaled[2,4]
        delta1_2 = all_sats_scaled[1,4] - all_sats_scaled[3,4]
        delta1_3 = all_sats_scaled[2,4] - all_sats_scaled[3,4]

        delta2_1 = all_sats_scaled[4,4] - all_sats_scaled[5,4]
        delta2_2 = all_sats_scaled[4,4]- all_sats_scaled[6,4]
        delta2_3 = all_sats_scaled[5,4] - all_sats_scaled[6,4]

        #these are the delta t measurments
        delta_t = [delta1_1 delta1_2 delta1_3; delta2_1 delta2_2 delta2_3]

        
        X = NaN*[zeros(4) for i = 1:1000]
        R = NaN*[zeros(2) for i = 1:1000]
        
        #Centroid guess
        X[1] = [guess[1]/distance_scale, guess[2]/distance_scale, guess[3]/distance_scale, 0.0001/time_scale]


        #Initial residual
        R[1] = residual(X[1], all_sats_noise, delta_t)

        iters = 0

        for k=1:1000
            R[k] = residual(X[k], all_sats_noise, delta_t)
            
            #println("this is residual: ", norm(R[k]))

            iters += 1
        
            #original tolerancec 1e-12
            
            if(norm(R[k]) < 1e-10)
                #print("residual low")

                break

            end

            jacobian = ForwardDiff.jacobian(dx -> residual(dx, all_sats_noise, delta_t), X[k])

            conditionnum = cond(jacobian)
            
            if iters>50
                break
            end
            
            #println("this is the jacobian: ", jacobian)
            #println("condition nubmer: ", conditionnum)

            deltax = (jacobian)\-R[k]
            
            #println("this is deltax: ", deltax)
            
            while norm(residual(X[k] + α*deltax, all_sats_noise, delta_t)) > norm(residual(X[k], all_sats_noise, delta_t) + b*α*jacobian*deltax)

                α = c*α
                #print("this is alpha: ", α)
            end

            X[k+1] = X[k] + α*deltax
            
        end  
        
        R = R[1:iters]
        X = X[1:iters]

        all_r0[i] = X[end]

    end
    x_values = zeros(n)
    y_values = zeros(n)
    z_values = zeros(n)

    for j in 1:n

        x_values[j] = all_r0[j][1]
        y_values[j] = all_r0[j][2]
        z_values[j] = all_r0[j][3]

    end
    
    #mean calculation
    mean = sum(all_r0, dims = 1)/ n
    mean = mean[1]
    mean_rescaled = [mean[1:3]*distance_scale*1e3; mean[4]*time_scale] # in meters
    #print("done")
    return mean_rescaled, all_r0, iters
end
# Out:
# receiver_pose (generic function with 1 method)

# %%
size(eci_1)[2]
# Out:
# 5670

# %%
#Navigation
#count = 0
n=1000
antenna_sep = 1
PDOP_array = zeros(size(eci_1)[2],1)
for i=1:size(eci_1)[2]
    
    #TEC = rand(d,4) #vTEC for each satellite from custom distribution
    
    satposes = [eci_1[1,i] eci_1[2,i] eci_1[3,i];eci_3[1,i] eci_3[2,i] eci_3[3,i]]
    
    zenith_angles = zenith_angle(satposes, r0[1:3])

    #check all angles to see if it is on the horizon 
    
    inhorizon = all(x->x<70, zenith_angles)
    
    if inhorizon==false
        #PDOP_array[i,1] = NaN
        continue #skip the current iteration
    end

    #Find for antenna 1
    #In km then to custom units
    r1_1 = [eci_1[1,i], eci_1[2,i], eci_1[3,i], 0]*1e-3/distance_scale
    #r2_1 = [eci_2[1,i], eci_2[2,i], eci_2[3,i], 0]*1e-3/distance_scale
    r3_1 = [eci_3[1,i], eci_3[2,i], eci_3[3,i], 0]*1e-3/distance_scale
    #r4_1 = [eci_4[1,i], eci_4[2,i], eci_4[3,i], 0]*1e-3/distance_scale
    
    t_1 = get_time(r0_scaled, r1_1, r3_1) #get the measurments at the tag position

    #Find time for antenna 2
    #In km then to custom units. currently 3 m apart 
    r1_2 = [eci_1[1,i]+antenna_sep, eci_1[2,i], eci_1[3,i], 0]*1e-3/distance_scale
    #r2_2 = [eci_2[1,i]+0.1, eci_2[2,i], eci_2[3,i], 0]*1e-3/distance_scale
    r3_2 = [eci_3[1,i]+antenna_sep, eci_3[2,i], eci_3[3,i], 0]*1e-3/distance_scale
    #r4_2 = [eci_4[1,i]+3, eci_4[2,i], eci_4[3,i], 0]*1e-3/distance_scale
    
    t_2 = get_time(r0_scaled, r1_2, r3_2)

    
    #Find time for antenna 3
    #In km then to custom units
    r1_3 = [eci_1[1,i]-antenna_sep, eci_1[2,i], eci_1[3,i], 0]*1e-3/distance_scale
    #r2_3 = [eci_2[1,i]-0.1, eci_2[2,i], eci_2[3,i], 0]*1e-3/distance_scale
    r3_3 = [eci_3[1,i]-antenna_sep, eci_3[2,i], eci_3[3,i], 0]*1e-3/distance_scale
    #r4_3 = [eci_4[1,i]-3, eci_4[2,i], eci_4[3,i], 0]*1e-3/distance_scale
    
    t_3 = get_time(r0_scaled, r1_3, r3_3)
    
#     delta1_1 = t_1[1] - t_2[1]
#     delta1_2 = t_1[1] - t_3[1]
#     delta1_3 = t_2[1] - t_3[1]
    
#     delta2_1 = t_1[2] - t_2[2]
#     delta2_2 = t_1[2] - t_3[2]
#     delta2_3 = t_2[2] - t_3[2]
    
#     delta3_1 = t_1[3] - t_2[3]
#     delta3_2 = t_1[3] - t_3[3]
#     delta3_3 = t_2[3] - t_3[3]
    
#     delta4_1 = t_1[4] - t_2[4]
#     delta4_2 = t_1[4] - t_3[4]
#     delta4_3 = t_2[4] - t_3[4]
    
    r1_1[4] = t_1[1]
    #r2_1[4] = t_1[2]
    r3_1[4] = t_1[2]
    
    r1_2[4] = t_2[1]
    #r2_2[4] = t_2[2]
    r3_2[4] = t_2[2]
    
    r1_3[4] = t_3[1]
    #r2_3[4] = t_3[2]
    r3_3[4] = t_3[2]

    #delta_t = [delta1_1 delta1_2 delta1_3; delta2_1 delta2_2 delta2_3; delta3_1 delta3_2 delta3_3; delta4_1 delta4_2 delta4_3]
    
    #all_sats_scaled = vcat(r1_1',r2_1',r3_1',r1_2',r2_2',r3_2',r1_3',r2_3',r3_3')
    
    all_sats_scaled = vcat(r1_1',r1_2',r1_3',r3_1',r3_2',r3_3')
    
    #Generate a guess at the centroid of all 4 sats on the surface of the Earth. Scaled to km
    
    centroid_guess = [(eci_1[1,i]+eci_3[1,i])/4, (eci_1[2,i]+eci_3[2,i])/4, (eci_1[3,i]+eci_3[3,i])/4] 
    #centroid_guess = eci_2[1:3, i]
    onearth = sECEFtoGEOC(centroid_guess, use_degrees = true)
    geodetic = [onearth[1], onearth[2], 0]

    xyz_guess = sGEOCtoECEF(geodetic, use_degrees = true)*1e-3 #change to km

    #Find all possible positions from montecarlo and send unscaled guess
    mean_rescaled, all_r0, iters = receiver_pose(all_sats_scaled, xyz_guess, zenith_angles)
    
    all_r0_scaled = zeros(n,4)

    #Rescale back to units (m and s)
    for i in 1:n
    
        all_r0_scaled[i,:] = [all_r0[i][1:3]*distance_scale*1e3; all_r0[i][4]*time_scale]
        
    end

    totalsum = zeros(4,4)

    for i in 1:n
    
        value = all_r0_scaled[i,:] - mean_rescaled
        matrixvalue = value*transpose(value)
        totalsum += matrixvalue
    
    end

    covariancematrix = totalsum/n
    
    PDOP = sqrt(covariancematrix[1,1] + covariancematrix[2,2] + covariancematrix[3,3])
    PDOP_array[i,1] = PDOP
    off_actual = norm(mean_rescaled - r0)
    println("cov position erors: ", PDOP)
    println("Mean (m): ", mean_rescaled)
    println("Difference from Actual: ", off_actual)
    println("Iterations: ", iters)

end
# Out:
# cov position erors: 104821.77791429657
# Mean (m): [-6.229825480627272e6, -1.7828354593147852e6, -160487.01902092452, 9.999999999999994e-5]
# Difference from Actual: 248308.13881122362
# Iterations: 5
# cov position erors: 102001.8412260225
# Mean (m): [-6.228300366953551e6, -1.7784344148911964e6, -154324.55497466717, 9.999999999999994e-5]
# Difference from Actual: 240778.9225846783
# Iterations: 4
# cov position erors: 103903.32902242603
# Mean (m): [-6.2271292542786915e6, -1.7779490476839447e6, -149350.4222834691, 9.999999999999994e-5]
# Difference from Actual: 236994.31222314117
# Iterations: 4
# cov position erors: 98197.41629722418
# Mean (m): [-6.226615196320981e6, -1.7773674701684357e6, -146203.01670074894, 9.999999999999994e-5]
# Difference from Actual: 234471.61743931455
# Iterations: 4
# cov position erors: 100534.455878298
# Mean (m): [-6.225383538616023e6, -1.7769082883530413e6, -141382.3072255922, 9.999999999999994e-5]
# Difference from Actual: 230869.6527983798
# Iterations: 4
# cov position erors: 101906.76143097444
# Mean (m): [-6.223688389355396e6, -1.7732307420581547e6, -135234.89798850488, 9.999999999999994e-5]
# Difference from Actual: 223950.96012595977
# Iterations: 4
# cov position erors: 98480.5852057244
# Mean (m): [-6.223334323684707e6, -1.7744087946825328e6, -132830.25799284014, 9.999999999999994e-5]
# Difference from Actual: 223336.78089585347
# Iterations: 4
# cov position erors: 99868.94480050627
# Mean (m): [-6.2218232715083305e6, -1.77141491802571e6, -127341.17395899603, 9.999999999999994e-5]
# Difference from Actual: 217438.0678214959
# Iterations: 4
# cov position erors: 95121.38930922828
# Mean (m): [-6.22222809454484e6, -1.7758948120435192e6, -127032.32363408551, 9.999999999999994e-5]
# Difference from Actual: 220859.92215494538
# Iterations: 4
# cov position erors: 97046.55844616919
# Mean (m): [-6.2195630901649315e6, -1.7661816178335845e6, -118364.61703396415, 9.999999999999994e-5]
# Difference from Actual: 207639.27384345318
# Iterations: 4
# cov position erors: 98620.04528691465
# Mean (m): [-6.219123947247921e6, -1.7691740342856762e6, -116249.3100955368, 9.999999999999994e-5]
# Difference from Actual: 208734.50044680116
# Iterations: 4
# cov position erors: 91904.04441252735
# Mean (m): [-6.220328692531285e6, -1.7770168932427466e6, -118032.26161769294, 9.999999999999994e-5]
# Difference from Actual: 216297.52094191377
# Iterations: 4
# cov position erors: 91509.72761520733
# Mean (m): [-6.2189872565466e6, -1.7733869319847873e6, -113229.68167231402, 9.999999999999994e-5]
# Difference from Actual: 210457.2301772346
# Iterations: 4
# cov position erors: 92385.07597533648
# Mean (m): [-6.218092712778634e6, -1.7730893149346649e6, -109865.17416213089, 9.999999999999994e-5]
# Difference from Actual: 208229.25812954883
# Iterations: 4
# cov position erors: 91942.42636528908
# Mean (m): [-6.216733987826651e6, -1.768670004747494e6, -105001.1247053427, 9.999999999999994e-5]
# Difference from Actual: 201746.49109276469
# Iterations: 4
# cov position erors: 95215.94733228012
# Mean (m): [-6.215966144778864e6, -1.7698575259960922e6, -102159.87638664046, 9.999999999999994e-5]
# Difference from Actual: 201109.8071141201
# Iterations: 4
# cov position erors: 92046.39782541424
# Mean (m): [-6.215245720328488e6, -1.7681415626999335e6, -99137.35766779611, 9.999999999999994e-5]
# Difference from Actual: 197996.85566440402
# Iterations: 4
# cov position erors: 91753.23154591354
# Mean (m): [-6.214607379234968e6, -1.7680133084884982e6, -96464.04671802143, 9.999999999999994e-5]
# Difference from Actual: 196429.61287567022
# Iterations: 4
# cov position erors: 93513.83220698404
# Mean (m): [-6.21313639924201e6, -1.7637420069027217e6, -91800.08019913024, 9.999999999999994e-5]
# Difference from Actual: 190229.45971081697
# Iterations: 4
# cov position erors: 93665.424732755
# Mean (m): [-6.21228946304789e6, -1.762355611941014e6, -88726.36061660139, 9.999999999999994e-5]
# Difference from Actual: 187401.5771106772
# Iterations: 4
# cov position erors: 89542.87799058175
# Mean (m): [-6.212724392947231e6, -1.7667670288693076e6, -88718.34237374071, 9.999999999999994e-5]
# Difference from Actual: 191277.68876768055
# Iterations: 4
# cov position erors: 90334.29710582306
# Mean (m): [-6.211544149567796e6, -1.7631963677836799e6, -84828.52005253371, 9.999999999999994e-5]
# Difference from Actual: 186162.5288808594
# Iterations: 4
# cov position erors: 88828.98189737993
# Mean (m): [-6.210648403820447e6, -1.760384766970184e6, -81634.39020168745, 9.999999999999994e-5]
# Difference from Actual: 182094.7205307119
# Iterations: 4
# cov position erors: 91781.79169517885
# Mean (m): [-6.209556991124037e6, -1.7587051855008441e6, -78406.5838716787, 9.999999999999994e-5]
# Difference from Actual: 178977.03047883188
# Iterations: 4
# cov position erors: 91362.4532126853
# Mean (m): [-6.209191296718449e6, -1.7592274100719811e6, -76586.14108670491, 9.999999999999994e-5]
# Difference from Actual: 178573.86333159942
# Iterations: 4
# cov position erors: 88357.02308655874
# Mean (m): [-6.209623647855051e6, -1.7642368788021703e6, -76749.29907158065, 9.999999999999994e-5]
# Difference from Actual: 183156.3517008499
# Iterations: 4
# cov position erors: 90333.79210126237
# Mean (m): [-6.208035757216752e6, -1.758155873914978e6, -72272.05210904867, 9.999999999999994e-5]
# Difference from Actual: 175583.79496892027
# Iterations: 4
# cov position erors: 87722.76538659392
# Mean (m): [-6.208260424377794e6, -1.7614088172371013e6, -71809.53379581761, 9.999999999999994e-5]
# Difference from Actual: 178342.14592467019
# Iterations: 4
# cov position erors: 87956.20784013705
# Mean (m): [-6.207224479967578e6, -1.7578251660734494e6, -68619.3819540138, 9.999999999999994e-5]
# Difference from Actual: 173656.93905919633
# Iterations: 4
# cov position erors: 88964.83361734019
# Mean (m): [-6.206877098719614e6, -1.759289502047072e6, -67199.16417787223, 9.999999999999994e-5]
# Difference from Actual: 174354.77345420714
# Iterations: 4
# cov position erors: 86716.80546836357
# Mean (m): [-6.206436018214057e6, -1.7580372720092128e6, -65216.37112717825, 9.999999999999994e-5]
# Difference from Actual: 172381.15827339332
# Iterations: 4
# cov position erors: 90582.85490441122
# Mean (m): [-6.20537294296647e6, -1.7559338654656422e6, -62423.864509549014, 9.999999999999994e-5]
# Difference from Actual: 169227.04846085157
# Iterations: 4
# cov position erors: 87849.20351690878
# Mean (m): [-6.2051014651337005e6, -1.7553090670121494e6, -60818.63730598949, 9.999999999999994e-5]
# Difference from Actual: 168019.95251999595
# Iterations: 4
# cov position erors: 85411.58518430324
# Mean (m): [-6.204197090238324e6, -1.7506082944064373e6, -57885.26211706585, 9.999999999999994e-5]
# Difference from Actual: 162499.18929006136
# Iterations: 4
# cov position erors: 87765.30186110832
# Mean (m): [-6.2034254938937295e6, -1.7493592465080372e6, -55747.157239765445, 9.999999999999994e-5]
# Difference from Actual: 160457.31238417016
# Iterations: 3
# cov position erors: 87724.03071530761
# Mean (m): [-6.203709874832548e6, -1.7543132649786756e6, -55790.003076731635, 9.999999999999994e-5]
# Difference from Actual: 165088.67216918062
# Iterations: 3
# cov position erors: 84369.54125136904
# Mean (m): [-6.203546568245923e6, -1.7538106300094456e6, -54405.037352295265, 9.999999999999994e-5]
# Difference from Actual: 164130.6740618682
# Iterations: 4
# cov position erors: 86083.67039524122
# Mean (m): [-6.20231350922314e6, -1.748652331148558e6, -51288.75955506606, 9.999999999999994e-5]
# Difference from Actual: 158102.6530097097
# Iterations: 3
# cov position erors: 86481.39885627234
# Mean (m): [-6.201632201241148e6, -1.7465665309959303e6, -49267.56984304072, 9.999999999999994e-5]
# Difference from Actual: 155392.04625019903
# Iterations: 4
# cov position erors: 85607.7546683615
# Mean (m): [-6.201562011821679e6, -1.7481171720962538e6, -48436.511972315966, 9.999999999999994e-5]
# Difference from Actual: 156565.4876709415
# Iterations: 3
# cov position erors: 85631.88871854107
# Mean (m): [-6.2011283651981335e6, -1.7474642256390203e6, -46937.293134858286, 9.999999999999994e-5]
# Difference from Actual: 155419.52249059628
# Iterations: 3
# cov position erors: 85087.77342969472
# Mean (m): [-6.200365030384603e6, -1.7439756089212534e6, -44725.87982817142, 9.999999999999994e-5]
# Difference from Actual: 151352.2639721733
# Iterations: 3
# cov position erors: 84891.19941014996
# Mean (m): [-6.200032409112673e6, -1.7437350399975134e6, -43447.93939494608, 9.999999999999994e-5]
# Difference from Actual: 150694.67644016873
# Iterations: 3
# cov position erors: 81763.71650506508
# Mean (m): [-6.201029765519366e6, -1.7520461949435447e6, -44589.86218169087, 9.999999999999994e-5]
# Difference from Actual: 159029.1441794686
# Iterations: 3
# cov position erors: 84693.25236910766
# Mean (m): [-6.199757944061721e6, -1.7463233034057624e6, -41759.209502748905, 9.999999999999994e-5]
# Difference from Actual: 152616.28949086546
# Iterations: 3
# cov position erors: 85451.07976917819
# Mean (m): [-6.199364115703334e6, -1.7459749919122637e6, -40480.20704471215, 9.999999999999994e-5]
# Difference from Actual: 151873.86176749543
# Iterations: 3
# cov position erors: 84238.08816647602
# Mean (m): [-6.198901371651447e6, -1.7439337514886395e6, -38900.764877777925, 9.999999999999994e-5]
# Difference from Actual: 149440.91412273937
# Iterations: 3
# cov position erors: 83340.64045805234
# Mean (m): [-6.197844215451866e6, -1.737322094827914e6, -36219.06604781029, 9.999999999999994e-5]
# Difference from Actual: 142281.5272981861
# Iterations: 4
# cov position erors: 82256.21406129905
# Mean (m): [-6.198604294722429e6, -1.7448076633849423e6, -37003.20043187326, 9.999999999999994e-5]
# Difference from Actual: 149742.29636645498
# Iterations: 3
# cov position erors: 85342.84543671727
# Mean (m): [-6.1973400638507195e6, -1.7388942975348143e6, -34470.9143814895, 9.999999999999994e-5]
# Difference from Actual: 143264.75421709628
# Iterations: 4
# cov position erors: 85280.46025131995
# Mean (m): [-6.196963339493832e6, -1.7379311243234675e6, -33256.904607033954, 9.999999999999994e-5]
# Difference from Actual: 141992.45923460906
# Iterations: 3
# cov position erors: 83152.25204393135
# Mean (m): [-6.196870803359822e6, -1.7378900655018592e6, -32327.650578350378, 9.999999999999994e-5]
# Difference from Actual: 141723.13284123523
# Iterations: 3
# cov position erors: 83179.1692192436
# Mean (m): [-6.1965310214071255e6, -1.7372081489255626e6, -31217.14715791138, 9.999999999999994e-5]
# Difference from Actual: 140762.9173777925
# Iterations: 3
# cov position erors: 82571.79539754997
# Mean (m): [-6.196189889206793e6, -1.7359906311941429e6, -30030.484242256498, 9.999999999999994e-5]
# Difference from Actual: 139276.60035925015
# Iterations: 3
# cov position erors: 84132.00367022169
# Mean (m): [-6.195859345336809e6, -1.7363007130669672e6, -29162.39211625595, 9.999999999999994e-5]
# Difference from Actual: 139338.12034068847
# Iterations: 4
# cov position erors: 82393.94651703675
# Mean (m): [-6.195498028086595e6, -1.7340134970672196e6, -27826.755593234393, 9.999999999999994e-5]
# Difference from Actual: 136796.80232443975
# Iterations: 3
# cov position erors: 82018.38907608582
# Mean (m): [-6.194663229526952e6, -1.7289205112890902e6, -25944.82337587396, 9.999999999999994e-5]
# Difference from Actual: 131363.33534110186
# Iterations: 3
# cov position erors: 83141.00122352467
# Mean (m): [-6.194507165601898e6, -1.730069180834082e6, -25336.62911415559, 9.999999999999994e-5]
# Difference from Actual: 132332.30263238022
# Iterations: 3
# cov position erors: 83737.04377363768
# Mean (m): [-6.19448916381646e6, -1.7320580944054378e6, -24896.677608114198, 9.999999999999994e-5]
# Difference from Actual: 134175.0151100085
# Iterations: 3
# cov position erors: 82475.92267286254
# Mean (m): [-6.194243846012766e6, -1.7307401068425134e6, -23846.92690936239, 9.999999999999994e-5]
# Difference from Actual: 132665.63818517182
# Iterations: 3
# cov position erors: 82627.83020948361
# Mean (m): [-6.193270657486782e6, -1.7245973340367966e6, -21951.69983776115, 9.999999999999994e-5]
# Difference from Actual: 126209.09327423724
# Iterations: 3
# cov position erors: 83044.33611524905
# Mean (m): [-6.193569546792999e6, -1.7289186429210992e6, -21965.884121474242, 9.999999999999994e-5]
# Difference from Actual: 130462.93354986723
# Iterations: 3
# cov position erors: 82334.92902225775
# Mean (m): [-6.193429776207338e6, -1.7288413294722885e6, -21194.262890620077, 9.999999999999994e-5]
# Difference from Actual: 130238.62974575195
# Iterations: 3
# cov position erors: 83101.53448034405
# Mean (m): [-6.193243411943404e6, -1.7294261366293023e6, -20561.619717058144, 9.999999999999994e-5]
# Difference from Actual: 130679.86776731734
# Iterations: 3
# cov position erors: 79963.80763294849
# Mean (m): [-6.1929128042311305e6, -1.7259697388003499e6, -19224.61321976329, 9.999999999999994e-5]
# Difference from Actual: 127048.58045800625
# Iterations: 3
# cov position erors: 81106.1193540269
# Mean (m): [-6.192769143512342e6, -1.726988712195805e6, -18690.6737098614, 9.999999999999994e-5]
# Difference from Actual: 127943.60097172565
# Iterations: 3
# cov position erors: 80408.62387073708
# Mean (m): [-6.192809554015646e6, -1.7283263184310626e6, -18181.989952237047, 9.999999999999994e-5]
# Difference from Actual: 129185.45825539588
# Iterations: 3
# cov position erors: 82243.53446423361
# Mean (m): [-6.191578686845786e6, -1.7204459157241802e6, -16351.780736615083, 9.999999999999994e-5]
# Difference from Actual: 121033.3804099871
# Iterations: 3
# cov position erors: 80472.37855190996
# Mean (m): [-6.1919738109196285e6, -1.7239394047138984e6, -16157.27777478832, 9.999999999999994e-5]
# Difference from Actual: 124490.1113890676
# Iterations: 3
# cov position erors: 81228.13535623284
# Mean (m): [-6.191673258775803e6, -1.7230915960541414e6, -15399.316539693264, 9.999999999999994e-5]
# Difference from Actual: 123518.01784442832
# Iterations: 3
# cov position erors: 81893.31921631953
# Mean (m): [-6.191167530110898e6, -1.720633589079054e6, -14443.692633172093, 9.999999999999994e-5]
# Difference from Actual: 120914.59045494812
# Iterations: 3
# cov position erors: 80208.58554708202
# Mean (m): [-6.191262740986796e6, -1.721506167549215e6, -13869.215303666104, 9.999999999999994e-5]
# Difference from Actual: 121718.71129893429
# Iterations: 3
# cov position erors: 83406.03789642542
# Mean (m): [-6.190803359156322e6, -1.7208866609812074e6, -13287.219867960775, 9.999999999999994e-5]
# Difference from Actual: 120978.77639068155
# Iterations: 3
# cov position erors: 81599.3671849714
# Mean (m): [-6.191030770410762e6, -1.7229799709338527e6, -12863.570344444905, 9.999999999999994e-5]
# Difference from Actual: 123025.64372511
# Iterations: 3
# cov position erors: 80900.61407495692
# Mean (m): [-6.19048920817101e6, -1.7188164073392642e6, -11721.385225490372, 9.999999999999994e-5]
# Difference from Actual: 118732.98936780586
# Iterations: 3
# cov position erors: 79745.48066273688
# Mean (m): [-6.190403199518208e6, -1.718399900653072e6, -11026.279517789197, 9.999999999999994e-5]
# Difference from Actual: 118243.73005608002
# Iterations: 3
# cov position erors: 80295.9048881194
# Mean (m): [-6.190179421977845e6, -1.7179102763924473e6, -10410.597266592225, 9.999999999999994e-5]
# Difference from Actual: 117673.61160147325
# Iterations: 3
# cov position erors: 79646.2505835649
# Mean (m): [-6.189811056876252e6, -1.7152771259205756e6, -9520.717830529129, 9.999999999999994e-5]
# Difference from Actual: 114948.36737471577
# Iterations: 3
# cov position erors: 79343.77969818859
# Mean (m): [-6.189089594290704e6, -1.7097710004535213e6, -8394.735584425576, 9.999999999999994e-5]
# Difference from Actual: 109323.33844134811
# Iterations: 3
# cov position erors: 78597.8813129808
# Mean (m): [-6.189259325365001e6, -1.7116071737762883e6, -7979.388060384054, 9.999999999999994e-5]
# Difference from Actual: 111129.18359869577
# Iterations: 3
# cov position erors: 80183.79085905812
# Mean (m): [-6.189007208035764e6, -1.7114797643129036e6, -7521.573428734111, 9.999999999999994e-5]
# Difference from Actual: 110936.34155827657
# Iterations: 3
# cov position erors: 81304.85846286564
# Mean (m): [-6.188919269653999e6, -1.7124483371632032e6, -7145.063864501249, 9.999999999999994e-5]
# Difference from Actual: 111856.83734897002
# Iterations: 3
# cov position erors: 79561.71207732208
# Mean (m): [-6.188519270078036e6, -1.7084419989920962e6, -6159.947742107592, 9.999999999999994e-5]
# Difference from Actual: 107781.20312733331
# Iterations: 3
# cov position erors: 78846.94476485871
# Mean (m): [-6.188221479278661e6, -1.7061909617995424e6, -5419.91440476172, 9.999999999999994e-5]
# Difference from Actual: 105473.77897801674
# Iterations: 3
# cov position erors: 81548.96237361828
# Mean (m): [-6.18822887168337e6, -1.708925893660637e6, -5314.871946352181, 9.999999999999994e-5]
# Difference from Actual: 108175.57342218167
# Iterations: 3
# cov position erors: 80077.46054410204
# Mean (m): [-6.188176366672511e6, -1.7081621267061692e6, -4624.3193489221985, 9.999999999999994e-5]
# Difference from Actual: 107380.66598293382
# Iterations: 3
# cov position erors: 80967.67010370226
# Mean (m): [-6.187592429354146e6, -1.7043685523970877e6, -3961.7412655358166, 9.999999999999994e-5]
# Difference from Actual: 103519.2370834823
# Iterations: 3
# cov position erors: 78095.1389863773
# Mean (m): [-6.187835259497744e6, -1.705057151674243e6, -3250.3490968352726, 9.999999999999994e-5]
# Difference from Actual: 104209.16955850585
# Iterations: 3
# cov position erors: 79745.94806916347
# Mean (m): [-6.187507008791074e6, -1.7040221834357688e6, -2854.1632630383547, 9.999999999999994e-5]
# Difference from Actual: 103128.21054688895
# Iterations: 4
# cov position erors: 79308.75934525295
# Mean (m): [-6.1876459735820675e6, -1.7056052755316389e6, -2398.7021241082293, 9.999999999999994e-5]
# Difference from Actual: 104703.66053815262
# Iterations: 4
# cov position erors: 78117.59385659016
# Mean (m): [-6.187699329808981e6, -1.7057796397676996e6, -1788.5256666165799, 9.999999999999994e-5]
# Difference from Actual: 104871.353071958
# Iterations: 3
# cov position erors: 79475.14977713377
# Mean (m): [-6.187282383395304e6, -1.7037469484174396e6, -1326.6607361577505, 9.999999999999994e-5]
# Difference from Actual: 102794.61113447556
# Iterations: 3
# cov position erors: 79314.52560218718
# Mean (m): [-6.187118912239114e6, -1.702760932186092e6, -777.6519665681207, 9.999999999999994e-5]
# Difference from Actual: 101790.05691010192
# Iterations: 3
# cov position erors: 79530.21406039601
# Mean (m): [-6.18733362260554e6, -1.705580944294433e6, -408.69612857106154, 9.999999999999994e-5]
# Difference from Actual: 104611.72266431252
# Iterations: 4
# cov position erors: 79180.94422227815
# Mean (m): [-6.186980521020274e6, -1.7027566386660077e6, 213.30367374095087, 9.999999999999994e-5]
# Difference from Actual: 101764.91202754622
# Iterations: 3
# cov position erors: 78471.82255566964
# Mean (m): [-6.186980812549904e6, -1.7027888293045035e6, 789.381524880842, 9.999999999999994e-5]
# Difference from Actual: 101799.70284286169
# Iterations: 4
# cov position erors: 78238.76484298446
# Mean (m): [-6.1867280886465e6, -1.700841871098572e6, 1347.0041696976164, 9.999999999999994e-5]
# Difference from Actual: 99842.43985807593
# Iterations: 4
# cov position erors: 77986.37096471479
# Mean (m): [-6.186060807158388e6, -1.6951793853158788e6, 1925.4176650212396, 9.999999999999994e-5]
# Difference from Actual: 94151.92532918497
# Iterations: 3
# cov position erors: 79914.1142346175
# Mean (m): [-6.186371132392257e6, -1.6997700226618047e6, 2132.5176543929924, 9.999999999999994e-5]
# Difference from Actual: 98747.36739128834
# Iterations: 4
# cov position erors: 77343.05512872046
# Mean (m): [-6.186163026599048e6, -1.6962079050688408e6, 2983.9702716183156, 9.999999999999994e-5]
# Difference from Actual: 95212.05182954416
# Iterations: 4
# cov position erors: 76615.01769474144
# Mean (m): [-6.185681455002438e6, -1.6918285123446838e6, 3534.0411830368084, 9.999999999999994e-5]
# Difference from Actual: 90829.35932846344
# Iterations: 4
# cov position erors: 79540.27547022769
# Mean (m): [-6.186116150583416e6, -1.6981274247752205e6, 3679.918491427009, 9.999999999999994e-5]
# Difference from Actual: 97132.34509492794
# Iterations: 4
# cov position erors: 76173.27610384481
# Mean (m): [-6.18570383286544e6, -1.6920234679113103e6, 4594.821327504982, 9.999999999999994e-5]
# Difference from Actual: 91072.76817781742
# Iterations: 4
# cov position erors: 77878.22150994177
# Mean (m): [-6.185872511533142e6, -1.695012188725959e6, 4908.428374280313, 9.999999999999994e-5]
# Difference from Actual: 94070.06438251479
# Iterations: 4
# cov position erors: 76956.0015032961
# Mean (m): [-6.185137287635692e6, -1.6881470278765063e6, 5343.984490826843, 9.999999999999994e-5]
# Difference from Actual: 87203.39993884924
# Iterations: 4
# cov position erors: 76825.66971165243
# Mean (m): [-6.185567225050296e6, -1.6917489729707476e6, 6020.353372591343, 9.999999999999994e-5]
# Difference from Actual: 90866.38425316998
# Iterations: 4
# cov position erors: 78393.12819624852
# Mean (m): [-6.185291755291474e6, -1.690677890468754e6, 6228.697504978055, 9.999999999999994e-5]
# Difference from Actual: 89785.22576074663
# Iterations: 4
# cov position erors: 74923.5876547917
# Mean (m): [-6.184872970245156e6, -1.684564971579995e6, 7019.575479355014, 9.999999999999994e-5]
# Difference from Actual: 83748.71201769881
# Iterations: 4
# cov position erors: 78753.39837242934
# Mean (m): [-6.185334541351454e6, -1.691326800900838e6, 7263.007786243323, 9.999999999999994e-5]
# Difference from Actual: 90509.79902404844
# Iterations: 4
# cov position erors: 74922.4246082054
# Mean (m): [-6.185248631355977e6, -1.6874328703664711e6, 8305.67573708547, 9.999999999999994e-5]
# Difference from Actual: 86744.93179408902
# Iterations: 4
# cov position erors: 76890.29628136862
# Mean (m): [-6.184969588185515e6, -1.6865468674591135e6, 8420.06828319731, 9.999999999999994e-5]
# Difference from Actual: 85845.12345739463
# Iterations: 4
# cov position erors: 76824.61899347253
# Mean (m): [-6.185039134572075e6, -1.6869169002849485e6, 9035.107829959949, 9.999999999999994e-5]
# Difference from Actual: 86281.52738423299
# Iterations: 4
# cov position erors: 73903.97739876262
# Mean (m): [-6.18471747643126e6, -1.681805765063603e6, 9754.098423176407, 9.999999999999994e-5]
# Difference from Actual: 81286.44591295844
# Iterations: 4
# cov position erors: 73959.40639365325
# Mean (m): [-6.184523151460144e6, -1.6800678376915099e6, 10149.747023290833, 9.999999999999994e-5]
# Difference from Actual: 79600.65822750423
# Iterations: 4
# cov position erors: 75646.00677537081
# Mean (m): [-6.184815463755098e6, -1.683300439539689e6, 10758.714176669202, 9.999999999999994e-5]
# Difference from Actual: 82894.37426283484
# Iterations: 4
# cov position erors: 75433.50172361208
# Mean (m): [-6.184727188017751e6, -1.682040178522349e6, 11300.596421944418, 9.999999999999994e-5]
# Difference from Actual: 81717.7850401169
# Iterations: 4
# cov position erors: 74442.89245015242
# Mean (m): [-6.184605685075028e6, -1.6799356131410862e6, 11915.901016325555, 9.999999999999994e-5]
# Difference from Actual: 79726.80813570743
# Iterations: 4
# cov position erors: 77405.1546794018
# Mean (m): [-6.184911272883197e6, -1.6841864944803547e6, 12426.28341014157, 9.999999999999994e-5]
# Difference from Actual: 84008.22488230158
# Iterations: 4
# cov position erors: 73845.16715248032
# Mean (m): [-6.185171424279988e6, -1.682599711575686e6, 13856.451581688136, 9.999999999999994e-5]
# Difference from Actual: 82717.11012418816
# Iterations: 4
# cov position erors: 77499.8373364752
# Mean (m): [-6.185175578172883e6, -1.685093154739199e6, 13995.985424457096, 9.999999999999994e-5]
# Difference from Actual: 85176.01257253521
# Iterations: 4
# cov position erors: 74377.1966655879
# Mean (m): [-6.184994884988693e6, -1.6803693825122165e6, 14921.63997935669, 9.999999999999994e-5]
# Difference from Actual: 80706.78690254077
# Iterations: 4
# cov position erors: 77860.03506758083
# Mean (m): [-6.184994152483258e6, -1.6824847931795958e6, 15089.322116033103, 9.999999999999994e-5]
# Difference from Actual: 82796.31884236823
# Iterations: 4
# cov position erors: 72922.36977748654
# Mean (m): [-6.18469978429622e6, -1.6753829308483896e6, 16087.199747876833, 9.999999999999994e-5]
# Difference from Actual: 76059.60563213556
# Iterations: 4
# cov position erors: 74622.92991433176
# Mean (m): [-6.184972876149848e6, -1.67787953340241e6, 16958.571633129737, 9.999999999999994e-5]
# Difference from Actual: 78697.38917020017
# Iterations: 4
# cov position erors: 76174.1359066168
# Mean (m): [-6.185240237317167e6, -1.6801652936164488e6, 17856.994337178956, 9.999999999999994e-5]
# Difference from Actual: 81138.13745704576
# Iterations: 4
# cov position erors: 76979.71130004396
# Mean (m): [-6.185114182344636e6, -1.6788539971698134e6, 18297.07277668497, 9.999999999999994e-5]
# Difference from Actual: 79954.83829034373
# Iterations: 4
# cov position erors: 73963.47553082516
# Mean (m): [-6.185163081586007e6, -1.6754820696451955e6, 19597.03570747314, 9.999999999999994e-5]
# Difference from Actual: 77040.87484214107
# Iterations: 4
# cov position erors: 77666.74393956292
# Mean (m): [-6.1853024845085e6, -1.6785656246352603e6, 20078.548442038944, 9.999999999999994e-5]
# Difference from Actual: 80132.08060341803
# Iterations: 4
# cov position erors: 74928.40211362093
# Mean (m): [-6.185263902938375e6, -1.6744593451758588e6, 21232.304569390686, 9.999999999999994e-5]
# Difference from Actual: 76516.93591119905
# Iterations: 4
# cov position erors: 75525.60826236653
# Mean (m): [-6.185349334734758e6, -1.674018767292557e6, 22123.427975500912, 9.999999999999994e-5]
# Difference from Actual: 76365.45259596933
# Iterations: 4
# cov position erors: 77579.51827523683
# Mean (m): [-6.186025027553531e6, -1.6786469565689256e6, 23954.164588244897, 9.999999999999994e-5]
# Difference from Actual: 81372.99776794927
# Iterations: 4
# cov position erors: 78453.6428136332
# Mean (m): [-6.18585380952895e6, -1.676667222042259e6, 24405.239699208312, 9.999999999999994e-5]
# Difference from Actual: 79618.32990313957
# Iterations: 4
# cov position erors: 74371.56520542198
# Mean (m): [-6.185904390504799e6, -1.6714802044304986e6, 26101.52878456096, 9.999999999999994e-5]
# Difference from Actual: 75344.86232101015
# Iterations: 4

# %%
final_PDOP = PDOP_array[PDOP_array .!=0]

PDOP_max = findmax(final_PDOP)[1]
PDOP_min = findmin(final_PDOP)[1]

println("Maximum PDOP: ", PDOP_max)
println("Minimum PDOP: ", PDOP_min)
# Out:
# Maximum PDOP: 104821.77791429657
# Minimum PDOP: 72922.36977748654
# KERNEL EXCEPTION
# UndefVarError: setexcludinghandlers! not defined
#
# Stacktrace:
#   [1] set_nosync(ob::Observables.Observable{Dict{Any, Any}}, val::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:352
#   [2] dispatch(ctx::WebIO.Scope, key::String, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:368
#   [3] dispatch_command(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:104
#   [4] dispatch(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:81
#   [5] (::WebIO.var"#93#94"{WebIO.IJuliaConnection})(msg::IJulia.Msg)
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/providers/ijulia.jl:21
#   [6] comm_msg(sock::ZMQ.Socket, msg::IJulia.Msg)
#     @ IJulia.CommManager ~/.julia/packages/IJulia/e8kqU/src/comm_manager.jl:134
#   [7] #invokelatest#2
#     @ ./essentials.jl:708 [inlined]
#   [8] invokelatest
#     @ ./essentials.jl:706 [inlined]
#   [9] eventloop(socket::ZMQ.Socket)
#     @ IJulia ~/.julia/packages/IJulia/e8kqU/src/eventloop.jl:8
#  [10] (::IJulia.var"#15#18")()
#     @ IJulia ./task.jl:411
# KERNEL EXCEPTION
# UndefVarError: setexcludinghandlers! not defined
#
# Stacktrace:
#   [1] set_nosync(ob::Observables.Observable{Dict{Any, Any}}, val::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:352
#   [2] dispatch(ctx::WebIO.Scope, key::String, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:368
#   [3] dispatch_command(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:104
#   [4] dispatch(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:81
#   [5] (::WebIO.var"#93#94"{WebIO.IJuliaConnection})(msg::IJulia.Msg)
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/providers/ijulia.jl:21
#   [6] comm_msg(sock::ZMQ.Socket, msg::IJulia.Msg)
#     @ IJulia.CommManager ~/.julia/packages/IJulia/e8kqU/src/comm_manager.jl:134
#   [7] #invokelatest#2
#     @ ./essentials.jl:708 [inlined]
#   [8] invokelatest
#     @ ./essentials.jl:706 [inlined]
#   [9] eventloop(socket::ZMQ.Socket)
#     @ IJulia ~/.julia/packages/IJulia/e8kqU/src/eventloop.jl:8
#  [10] (::IJulia.var"#15#18")()
#     @ IJulia ./task.jl:411
# KERNEL EXCEPTION
# UndefVarError: setexcludinghandlers! not defined
#
# Stacktrace:
#   [1] set_nosync(ob::Observables.Observable{Dict{Any, Any}}, val::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:352
#   [2] dispatch(ctx::WebIO.Scope, key::String, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:368
#   [3] dispatch_command(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:104
#   [4] dispatch(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:81
#   [5] (::WebIO.var"#93#94"{WebIO.IJuliaConnection})(msg::IJulia.Msg)
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/providers/ijulia.jl:21
#   [6] comm_msg(sock::ZMQ.Socket, msg::IJulia.Msg)
#     @ IJulia.CommManager ~/.julia/packages/IJulia/e8kqU/src/comm_manager.jl:134
#   [7] #invokelatest#2
#     @ ./essentials.jl:708 [inlined]
#   [8] invokelatest
#     @ ./essentials.jl:706 [inlined]
#   [9] eventloop(socket::ZMQ.Socket)
#     @ IJulia ~/.julia/packages/IJulia/e8kqU/src/eventloop.jl:8
#  [10] (::IJulia.var"#15#18")()
#     @ IJulia ./task.jl:411
# KERNEL EXCEPTION
# UndefVarError: setexcludinghandlers! not defined
#
# Stacktrace:
#   [1] set_nosync(ob::Observables.Observable{Dict{Any, Any}}, val::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:352
#   [2] dispatch(ctx::WebIO.Scope, key::String, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:368
#   [3] dispatch_command(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:104
#   [4] dispatch(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:81
#   [5] (::WebIO.var"#93#94"{WebIO.IJuliaConnection})(msg::IJulia.Msg)
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/providers/ijulia.jl:21
#   [6] comm_msg(sock::ZMQ.Socket, msg::IJulia.Msg)
#     @ IJulia.CommManager ~/.julia/packages/IJulia/e8kqU/src/comm_manager.jl:134
#   [7] #invokelatest#2
#     @ ./essentials.jl:708 [inlined]
#   [8] invokelatest
#     @ ./essentials.jl:706 [inlined]
#   [9] eventloop(socket::ZMQ.Socket)
#     @ IJulia ~/.julia/packages/IJulia/e8kqU/src/eventloop.jl:8
#  [10] (::IJulia.var"#15#18")()
#     @ IJulia ./task.jl:411
# KERNEL EXCEPTION
# UndefVarError: setexcludinghandlers! not defined
#
# Stacktrace:
#   [1] set_nosync(ob::Observables.Observable{Dict{Any, Any}}, val::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:352
#   [2] dispatch(ctx::WebIO.Scope, key::String, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:368
#   [3] dispatch_command(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:104
#   [4] dispatch(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:81
#   [5] (::WebIO.var"#93#94"{WebIO.IJuliaConnection})(msg::IJulia.Msg)
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/providers/ijulia.jl:21
#   [6] comm_msg(sock::ZMQ.Socket, msg::IJulia.Msg)
#     @ IJulia.CommManager ~/.julia/packages/IJulia/e8kqU/src/comm_manager.jl:134
#   [7] #invokelatest#2
#     @ ./essentials.jl:708 [inlined]
#   [8] invokelatest
#     @ ./essentials.jl:706 [inlined]
#   [9] eventloop(socket::ZMQ.Socket)
#     @ IJulia ~/.julia/packages/IJulia/e8kqU/src/eventloop.jl:8
#  [10] (::IJulia.var"#15#18")()
#     @ IJulia ./task.jl:411
# KERNEL EXCEPTION
# UndefVarError: setexcludinghandlers! not defined
#
# Stacktrace:
#   [1] set_nosync(ob::Observables.Observable{Dict{Any, Any}}, val::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:352
#   [2] dispatch(ctx::WebIO.Scope, key::String, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:368
#   [3] dispatch_command(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:104
#   [4] dispatch(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:81
#   [5] (::WebIO.var"#93#94"{WebIO.IJuliaConnection})(msg::IJulia.Msg)
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/providers/ijulia.jl:21
#   [6] comm_msg(sock::ZMQ.Socket, msg::IJulia.Msg)
#     @ IJulia.CommManager ~/.julia/packages/IJulia/e8kqU/src/comm_manager.jl:134
#   [7] #invokelatest#2
#     @ ./essentials.jl:708 [inlined]
#   [8] invokelatest
#     @ ./essentials.jl:706 [inlined]
#   [9] eventloop(socket::ZMQ.Socket)
#     @ IJulia ~/.julia/packages/IJulia/e8kqU/src/eventloop.jl:8
#  [10] (::IJulia.var"#15#18")()
#     @ IJulia ./task.jl:411
# KERNEL EXCEPTION
# UndefVarError: setexcludinghandlers! not defined
#
# Stacktrace:
#   [1] set_nosync(ob::Observables.Observable{Dict{Any, Any}}, val::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:352
#   [2] dispatch(ctx::WebIO.Scope, key::String, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:368
#   [3] dispatch_command(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:104
#   [4] dispatch(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:81
#   [5] (::WebIO.var"#93#94"{WebIO.IJuliaConnection})(msg::IJulia.Msg)
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/providers/ijulia.jl:21
#   [6] comm_msg(sock::ZMQ.Socket, msg::IJulia.Msg)
#     @ IJulia.CommManager ~/.julia/packages/IJulia/e8kqU/src/comm_manager.jl:134
#   [7] #invokelatest#2
#     @ ./essentials.jl:708 [inlined]
#   [8] invokelatest
#     @ ./essentials.jl:706 [inlined]
#   [9] eventloop(socket::ZMQ.Socket)
#     @ IJulia ~/.julia/packages/IJulia/e8kqU/src/eventloop.jl:8
#  [10] (::IJulia.var"#15#18")()
#     @ IJulia ./task.jl:411
# KERNEL EXCEPTION
# UndefVarError: setexcludinghandlers! not defined
#
# Stacktrace:
#   [1] set_nosync(ob::Observables.Observable{Dict{Any, Any}}, val::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:352
#   [2] dispatch(ctx::WebIO.Scope, key::String, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:368
#   [3] dispatch_command(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:104
#   [4] dispatch(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:81
#   [5] (::WebIO.var"#93#94"{WebIO.IJuliaConnection})(msg::IJulia.Msg)
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/providers/ijulia.jl:21
#   [6] comm_msg(sock::ZMQ.Socket, msg::IJulia.Msg)
#     @ IJulia.CommManager ~/.julia/packages/IJulia/e8kqU/src/comm_manager.jl:134
#   [7] #invokelatest#2
#     @ ./essentials.jl:708 [inlined]
#   [8] invokelatest
#     @ ./essentials.jl:706 [inlined]
#   [9] eventloop(socket::ZMQ.Socket)
#     @ IJulia ~/.julia/packages/IJulia/e8kqU/src/eventloop.jl:8
#  [10] (::IJulia.var"#15#18")()
#     @ IJulia ./task.jl:411
# KERNEL EXCEPTION
# UndefVarError: setexcludinghandlers! not defined
#
# Stacktrace:
#   [1] set_nosync(ob::Observables.Observable{Dict{Any, Any}}, val::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:352
#   [2] dispatch(ctx::WebIO.Scope, key::String, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:368
#   [3] dispatch_command(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:104
#   [4] dispatch(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:81
#   [5] (::WebIO.var"#93#94"{WebIO.IJuliaConnection})(msg::IJulia.Msg)
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/providers/ijulia.jl:21
#   [6] comm_msg(sock::ZMQ.Socket, msg::IJulia.Msg)
#     @ IJulia.CommManager ~/.julia/packages/IJulia/e8kqU/src/comm_manager.jl:134
#   [7] #invokelatest#2
#     @ ./essentials.jl:708 [inlined]
#   [8] invokelatest
#     @ ./essentials.jl:706 [inlined]
#   [9] eventloop(socket::ZMQ.Socket)
#     @ IJulia ~/.julia/packages/IJulia/e8kqU/src/eventloop.jl:8
#  [10] (::IJulia.var"#15#18")()
#     @ IJulia ./task.jl:411
# KERNEL EXCEPTION
# UndefVarError: setexcludinghandlers! not defined
#
# Stacktrace:
#   [1] set_nosync(ob::Observables.Observable{Dict{Any, Any}}, val::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:352
#   [2] dispatch(ctx::WebIO.Scope, key::String, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:368
#   [3] dispatch_command(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:104
#   [4] dispatch(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:81
#   [5] (::WebIO.var"#93#94"{WebIO.IJuliaConnection})(msg::IJulia.Msg)
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/providers/ijulia.jl:21
#   [6] comm_msg(sock::ZMQ.Socket, msg::IJulia.Msg)
#     @ IJulia.CommManager ~/.julia/packages/IJulia/e8kqU/src/comm_manager.jl:134
#   [7] #invokelatest#2
#     @ ./essentials.jl:708 [inlined]
#   [8] invokelatest
#     @ ./essentials.jl:706 [inlined]
#   [9] eventloop(socket::ZMQ.Socket)
#     @ IJulia ~/.julia/packages/IJulia/e8kqU/src/eventloop.jl:8
#  [10] (::IJulia.var"#15#18")()
#     @ IJulia ./task.jl:411
# KERNEL EXCEPTION
# UndefVarError: setexcludinghandlers! not defined
#
# Stacktrace:
#   [1] set_nosync(ob::Observables.Observable{Dict{Any, Any}}, val::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:352
#   [2] dispatch(ctx::WebIO.Scope, key::String, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:368
#   [3] dispatch_command(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:104
#   [4] dispatch(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:81
#   [5] (::WebIO.var"#93#94"{WebIO.IJuliaConnection})(msg::IJulia.Msg)
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/providers/ijulia.jl:21
#   [6] comm_msg(sock::ZMQ.Socket, msg::IJulia.Msg)
#     @ IJulia.CommManager ~/.julia/packages/IJulia/e8kqU/src/comm_manager.jl:134
#   [7] #invokelatest#2
#     @ ./essentials.jl:708 [inlined]
#   [8] invokelatest
#     @ ./essentials.jl:706 [inlined]
#   [9] eventloop(socket::ZMQ.Socket)
#     @ IJulia ~/.julia/packages/IJulia/e8kqU/src/eventloop.jl:8
#  [10] (::IJulia.var"#15#18")()
#     @ IJulia ./task.jl:411
# KERNEL EXCEPTION
# UndefVarError: setexcludinghandlers! not defined
#
# Stacktrace:
#   [1] set_nosync(ob::Observables.Observable{Dict{Any, Any}}, val::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:352
#   [2] dispatch(ctx::WebIO.Scope, key::String, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/scope.jl:368
#   [3] dispatch_command(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:104
#   [4] dispatch(conn::WebIO.IJuliaConnection, data::Dict{String, Any})
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/messaging.jl:81
#   [5] (::WebIO.var"#93#94"{WebIO.IJuliaConnection})(msg::IJulia.Msg)
#     @ WebIO ~/.julia/packages/WebIO/4JqEH/src/providers/ijulia.jl:21
#   [6] comm_msg(sock::ZMQ.Socket, msg::IJulia.Msg)
#     @ IJulia.CommManager ~/.julia/packages/IJulia/e8kqU/src/comm_manager.jl:134
#   [7] #invokelatest#2
#     @ ./essentials.jl:708 [inlined]
#   [8] invokelatest
#     @ ./essentials.jl:706 [inlined]
#   [9] eventloop(socket::ZMQ.Socket)
#     @ IJulia ~/.julia/packages/IJulia/e8kqU/src/eventloop.jl:8
#  [10] (::IJulia.var"#15#18")()
#     @ IJulia ./task.jl:411

# %%
#write to a file
open("sat_data.txt", "w") do file
        writedlm(file, PDOP_array)
    end

# %%
PDOP_filtered = filter(!iszero, PDOP_array)
n = size(PDOP_filtered)[1]
timesteps = range(1, n; length = n)
#RAANsep = zeros(n)
#RAANsep .= 12

plot(

    heatmap(

        x=timesteps,

        y=[12],

        z=PDOP_filtered'

    ),

    Layout(xaxis_side="top")

)

# %%
#Equitorial Position
#In m
# x0= 5100.14e3 
# y0 = -5e3
# z0 = -1000e3
# t0 = 1e-5

# r0 = [x0,y0,z0,t0]

# Max_position = plot3d(eci_1[1,:], eci_1[2,:], eci_1[3,:], xlabel = "x", ylabel = "y", zlabel="z", title = "ISS Orbits")
# plot3d!(eci_3[1,:], eci_3[2,:], eci_3[3,:])
# scatter!([eci_1[1,500]], [eci_1[2,500]], [eci_1[3,500]], label ="satellite 1 end")
# scatter!([eci_2[1,500]], [eci_2[2,500]], [eci_2[3,500]], label ="satellite 2 end")
# scatter!([eci_3[1,500]], [eci_3[2,500]], [eci_3[3,500]], label ="satellite 3 end")
# scatter!([eci_4[1,500]], [eci_4[2,500]], [eci_4[3,500]], label ="satellite 4 end")

# scatter!([r0[1]], [r0[2]], [r0[3]], label ="Receiver Pose")

# %%
# using PlotlyJS
# r0 = [-6.128804e6, -1.590206e6, 706.1502e3]

# sat1 = scatter(x=eci_1[1,:], y=eci_1[2,:], z=eci_1[3,:], type="scatter3d", mode="lines", name="orbit 1&2")
# sat3 = scatter(x=eci_3[1,:], y=eci_3[2,:], z=eci_3[3,:], type="scatter3d", mode="lines", name="orbit 3&4")
# satellites = scatter(x=[eci_1[1,1],eci_2[1,1], eci_3[1,1], eci_4[1,1]], y=[eci_1[2,1],eci_2[2,1], eci_3[2,1], eci_4[2,1]],z=[eci_1[3,1],eci_2[3,1], eci_3[3,1], eci_4[3,1]], mode="markers", marker_size = 4, type="scatter3d", name="satellites")
# tag = scatter(x = [r0[1], r0[1]], y = [r0[2], r0[2]], z = [r0[3], r0[3]], type="scatter3d", name="tag", mode="markers", marker_size=5)
# guess = scatter(x = [xyz[1], xyz[1]], y = [xyz[2], xyz[2]], z = [xyz[3], xyz[3]], type="scatter3d", name="guess", mode="markers", marker_size=5)

# #Plotting the sphere (Earth)
# n = 100
# u = range(-π, π; length = n)
# v = range(0, π; length = n)
# x = cos.(u) * sin.(v)'
# y = sin.(u) * sin.(v)' 
# z = ones(n) * cos.(v)' 

# earth = surface(z=z*6371000, x=x*6371000, y=y*6371000)

# plot([sat1,sat3, satellites, tag, earth, guess])

# %%
currentguess = [-6069.837128422696e3, -1872.3495983074513e3, -576.2081281171355e3]
currentgoodguess = [-6122.192731259023, -1602.2259670043013, -795.1475980881328]
solution = [-6.12e6, -1.59e6, 707e3]
norm(currentguess-solution)*1e-3

# %%
norm(solution-currentgoodguess)*1e-3

# %%
print(R_EARTH)

# %%
print(C_LIGHT)

# %%
print(C_LIGHT/R_EARTH)

# %%
initial_guess_test = [-6008.070607599407, -2138.8401454269697, -95.29951300518883]

# %%
final_tag_position = [-6.128804e3, -1.590206e3, 706.1502]

# %%
goodxyzguess = [-6171.613952212497, -1607.061707221621, -95.73653851577275]

# %%
outloop = [-5.88796087165688e6, -1.6631186857729724e6, -1.801828127663494e6]*1e-3

# %%
norm(final_tag_position - outloop)

# %%
centroid_guess = [(eci_1[1,1]+eci_2[1,1]+eci_3[1,1]+eci_4[1,1])/4, (eci_1[2,1]+eci_2[2,1]+eci_3[2,1]+eci_4[2,1])/4, (eci_1[3,1]+eci_2[3,1]+eci_3[3,1]+eci_4[3,1])/4] 
#centroid_guess = eci_2[1:3, i]
onearth = sECEFtoGEOC(centroid_guess, use_degrees = true)
geodetic = [onearth[1], onearth[2], 0]

xyz_guess = sGEOCtoECEF(geodetic, use_degrees = true)#change to km
        
println("this is the initial guess!: ", xyz_guess)

# %%
[-5.916954261422363e6, -1.5603343331057036e6, -1.798788655717042e6]*1e-3

# %%
satposes = [eci_1[1,1] eci_1[2,1] eci_1[3,1];eci_2[1,1] eci_2[2,1] eci_2[3,1];eci_3[1,1] eci_3[2,1] eci_3[3,1];eci_4[1,1] eci_4[2,1] eci_4[3,1]]

# %%
log(9.586691825001129)
