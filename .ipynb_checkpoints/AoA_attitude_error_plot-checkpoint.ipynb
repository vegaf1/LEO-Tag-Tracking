# %%
#Plots 
using Plots
#4 sat TOA 1 frequency 

#AoA 3 sat plot
attitude = [0.1,0.05,0.0027,0.001,0.0005]
maxPDOP = [12255.145, 5820.926,333.522, 119.522,  66.050]
minPDOP = [1674.858, 817.400,44.872, 17.1693,  9.127]

plot(attitude, maxPDOP, label="Maximum Error")
plot!(attitude, minPDOP, label="Minimum Error")
xlabel!("Attitude Error (Degrees)")
ylabel!("Pose Covariance Error (m)")
title!("3 Satellite AOA/TDOA 1 frequency")

# %%
#AoA 4 sat plot
attitude = [0.003,0.0027,0.002,0.001,0.0005]
maxPDOP = [219.264, 214.5784, 109.117,  47.425,  25.053]
minPDOP = [49.217,  45.346,  33.0729,  17.065,  9.0498]

#plot(attitude, maxPDOP, label="Maximum Error")
plot(attitude, minPDOP, label="Minimum Error")
xlabel!("Attitude Error (Degrees)")
ylabel!("Pose Covariance Error (m)")
title!("4 Satellite AOA/TDOA 1 frequency")
